# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# Import the API key.
from Module_Challenge_config import weather_api_key
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(-21.23497506884644, 109.8218764629163), (-63.29848844568227, -152.06127691649968), (-41.052702378984606, 168.5530289874335), (57.75560990794659, -176.09511050248813), (49.402237251575315, -33.12491458764427), (69.58207044577566, 81.97908067354416), (-35.276947280443814, 27.80957343459906), (-51.772605736092025, -36.97955572207218), (-32.53905288768911, -153.12187399005555), (-61.22888511890721, 163.3141856857161), (70.05919106992232, -70.9610922876674), (-55.65268875347669, 3.3532720026113907), (74.71124695827424, 179.01814905392047), (-73.9332665629978, -30.571996334010407), (-52.63179308291865, -167.86752591858908), (-27.060201326462156, 35.55026503124975), (-65.98120420966742, 75.14354844522339), (10.868879604224276, 125.43305267544889), (-70.27088911663502, -78.77247488195398), (-64.24658129873814, 84.30817936981526), (67.86122464937517, 81.44220896303335), (-35.595784032377736, -60.84864808828071), (-43.227695120012804, -52.047359909708206), (-89.75761974094505, -85.53332441524522), (77.97950167192425, 86.61058595918871), (81.07607120493128, 58.12607298404188), (49.983396461514076, -1.3322790266794016), (48.532494423782055, -108.40502398302428), (-31.839559001776458, 162.16293776149), (16.53260871511597, 155.39305287434155), (-31.529357846020233, 112.68416186535626), (62.082070076858315, 171.65790998583878), (-71.39451215890458, 48.91019667517148), (12.338115283227523, 83.53809976225432), (-65.29173201565335, 142.45821317560728), (-42.061011724771944, -165.60121522428372), (-87.3400416222338, -57.48543059817921), (32.97287571284568, -59.935958907071466), (49.613639165167854, 94.32826176783396), (-7.738206971756924, -97.50036916345385), (-67.9251926783053, 114.92282842469331), (-35.43930795016368, 26.50670076049431), (-44.53883044519492, -170.75897181889988), (17.191400810956438, 166.90898517369664), (-38.408484813915116, 62.298911715022456), (-42.5339318587611, 27.617639593545874), (-86.100753163711, 113.86078248343165), (26.312179307991443, 32.949332140267586), (12.609861253156978, 177.69079004922042), (13.980282813600297, -21.432063387665806), (13.246062034863257, -44.33872394236491), (-76.94455069344694, 173.82050180086043), (-15.552493913630414, -121.50828812295568), (20.66812024952685, 30.96620713449363), (-1.602399418433933, 93.4627500399501), (54.858011054325516, 41.37439399132822), (64.82101843416422, 145.75179067286604), (25.067593791976478, 176.63755422176695), (69.46057627530774, 3.7962681536409377), (89.81708827676027, 54.82032680001021), (14.230397096873844, 144.16029224422857), (-88.62333849133454, 39.45752680998018), (65.6896193769451, 143.63123463314122), (29.778419787064394, 88.25786091781356), (-39.19543397641422, 51.14490185265939), (36.01648170418437, -82.33366360399972), (62.97424828386721, -89.2553527560184), (-34.48280674841721, 6.4306170698992275), (-21.668717804187878, 150.3452105620387), (87.78218535794116, -57.763892009041115), (29.185439156828977, -117.71706017390977), (-55.03159121048791, 8.856568714177769), (-11.097136687586442, 33.49001469212956), (38.93903846834402, -51.51503543189753), (51.98988174605202, -41.081834068608174), (25.203269120039977, -64.28652500828298), (-44.740462541229334, -89.14663226278277), (-58.40612756102494, -146.62085022517752), (-43.71634341765122, -149.47381425303425), (63.63231401244252, -45.717212851461), (58.27782409488219, 148.77008808634451), (-56.23969671420827, 95.71859851199747), (36.95082041684053, 55.715612994802854), (-30.070842765013964, 139.07378166149), (-24.754896961942023, -123.68585056962799), (43.0113149241966, -64.47094755183748), (-6.880066959202551, -7.369954691011799), (-37.95254438967247, 157.96426687241876), (-16.638093601483774, -96.97915393995697), (-47.73293980867228, 135.1819413602479), (35.114088379910356, -73.81946370438037), (-81.18312074320698, 102.03175238713686), (-75.69761585778855, -127.20328843231232), (-81.65792811482693, -170.57165479418745), (82.10463328829175, -91.81994496554766), (53.38826187776053, 59.28078648174727), ( ...

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Loop through all the cities in the list.
for city in cities:

    city_url = url + "&q=" + city.replace(" ","+")
   
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        print(city_lat, city_lng, city_country, city_max_temp, city_humidity, city_clouds, city_wind, description)

        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# -24.8667 113.6333 AU 63.91 59 96 12.66 overcast clouds
# -46.1927 168.8643 NZ 46.47 97 99 0.72 overcast clouds
# -42.7167 170.9667 NZ 53.55 75 80 3.15 broken clouds
# 64.3833 -173.3 RU 39.36 100 53 4 broken clouds
# 39.05 -27.9833 PT 73.96 82 18 5.77 few clouds
# City not found. Skipping...
# -33.5906 26.891 ZA 58.62 75 10 9.31 clear sky
# -33.6971 -53.4616 UY 53.73 79 100 10.74 overcast clouds
# -46.6 168.3333 NZ 46.8 87 100 2.42 overcast clouds
# 70.4692 -68.5914 CA 32.23 86 75 5.75 snow
# -33.9258 18.4232 ZA 64.38 67 0 9.22 clear sky
# 69.3833 178.4167 RU 33.1 75 6 13.67 clear sky
# -54.8 -68.3 AR 49.66 43 0 10.36 clear sky
# -21.2 -175.2 TO 75.36 88 40 9.22 scattered clouds
# -25.0519 33.6442 MZ 67.06 95 100 14.12 moderate rain
# -21.3585 55.7679 RE 69.39 87 67 14.79 light rain
# 11.1097 125.3875 PH 78.42 86 100 1.5 overcast clouds
# -33.65 115.3333 AU 57.94 71 3 16.62 clear sky
# 65.7 82.4667 RU 36.37 64 100 18.88 light rain
# -35.4444 -60.8831 AR 57.96 41 99 4 light rain
# -38.0023 -57.5575 AR 53.62 70 0 9.22 clear sky
# 73.5069 80.5464 RU 30.42 72 100 19.55 overcast clouds
# City not found. Skipping...
# 49.6383 -1.5664 FR 51.22 87 0 2.3 clear sky
# 49.6501 -108.4181 CA 53.38 46 50 18.37 scattered clouds
# -28.8667 153.5667 AU 62.02 99 100 7.29 light rain
# -2.5744 150.7967 PG 81.55 77 93 9.42 light rain
# -32.25 115.7667 AU 54.34 75 2 12.84 clear sky
# City not found. Skipping...
# City not found. Skipping...
# -42.8794 147.3294 AU 53.46 68 100 8.05 overcast clouds
# -21.2078 -159.775 CK 73.45 83 75 12.66 broken clouds
# 37.1041 -113.5841 US 91.99 16 0 14.97 clear sky
# 36.9559 36.2 TR 73.67 88 39 2.46 scattered clouds
# -0.7393 -90.3518 EC 75.16 91 67 11.01 broken clouds
# 42.6001 -73.9662 US 73.17 75 42 1.99 scattered clouds
# -33.918 25.5701 ZA 56.1 90 0 3.44 clear sky
# 3.0707 172.7902 KI 81 76 95 11.92 overcast clouds
# 26.1615 32.7183 EG 81.61 27 0 8.84 clear sky
# 15.1333 -23.2167 CV 79.59 76 34 13.94 scattered clouds
# 4.9333 -52.3333 GF 77.04 83 37 5.75 scattered clouds
# -23.1203 -134.9692 PF 73.15 77 0 16.04 clear sky
# 7.9986 124.2928 PH 69.26 92 100 1.68 overcast clouds
# 1.7427 98.7792 ID 76.1 85 84 3.15 broken clouds
# 54.9411 41.3953 RU 48.22 78 61 2.46 broken clouds
# City not found. Skipping...
# 39.447 -86.1758 US 90.68 68 11 5.46 few clouds
# -8.9266 125.4092 TL 59.14 87 32 3.22 scattered clouds
# City not found. Skipping...
# 27.5167 88.5333 IN 73.42 91 91 1.41 overcast clouds
# City not found. Skipping...
# 36.3134 -82.3535 US 88.12 52 40 5.75 scattered clouds
# 55.7435 -97.8558 CA 44.76 81 100 11.5 overcast clouds
# -33.0117 17.9442 ZA 55.45 87 0 10.13 clear sky
# -21.15 149.2 AU 72.68 81 63 7.72 broken clouds
# 72.7868 -56.1549 GL 33.39 97 100 6.31 light snow
# 30.4833 -115.95 MX 74.53 66 77 15.52 broken clouds
# -34.4187 19.2345 ZA 53.8 77 0 9.28 clear sky
# 47.1821 8.4636 CH 53.82 78 75 1.14 broken clouds
# 47.6666 -52.7314 CA 54.27 77 20 9.22 few clouds
# 60.1432 -45.2371 GL 41.4 90 21 11.21 few clouds
# 18.4167 -64.6167 VG 87.89 84 40 10.36 scattered clouds
# -24.7911 -50.0119 BR 64.06 76 53 3.13 broken clouds
# 60.7167 -46.0333 GL 42.78 85 12 3.4 few clouds
# 59.7 150.1667 RU 41.02 88 100 6.85 overcast clouds
# 37.2289 55.3747 IR 71.92 39 0 3.76 clear sky
# -32.5 137.7667 AU 56.82 86 74 17.25 broken clouds
# 53.4106 -2.9779 GB 60.75 78 100 5.75 overcast clouds
# 5.4112 100.3354 MY 78.73 94 40 2.3 scattered clouds
# -32.7167 152.15 AU 64 88 100 10 light rain
# 45.5234 -122.6762 US 85.68 26 20 8.05 few clouds
# 36.2946 -76.2511 US 90.01 56 0 11.5 clear sky
# 77.484 -69.3632 GL 24.33 63 100 6.15 overcast clouds
# 53.2973 59.1348 RU 54.61 33 77 4.27 broken clouds
# 4.1363 96.1285 ID 75.78 91 100 4.52 overcast clouds
# 71.6872 128.8694 RU 31.98 96 100 10.87 light snow
# -33.0153 27.9116 ZA 59.58 71 38 7.11 scattered clouds
# 11.0167 29.7167 SD 74.59 85 99 1.77 overcast clouds
# 7.7669 -72.225 VE 78.98 54 67 2.19 broken clouds
# -41.8697 -73.8203 CL 47.23 77 42 5.1 light rain
# -53.15 -70.9167 CL 55.51 35 75 8.05 broken clouds
# 32.8333 66 AF 67.46 22 0 2.37 clear sky
# -42.7826 147.0587 AU 53.1 66 89 1.01 overcast clouds
# 0.8 127.4 ID 79.9 78 90 1.66 moderate rain
# 13.35 -15.75 GM 74.14 96 100 4.18 overcast clouds
# 38.5167 -28.7 PT 75.6 83 20 5.75 few clouds
# 61.6864 53.6902 RU 53.06 72 76 13.85 broken clouds
# -46.1333 167.6833 NZ 49.35 93 100 0.83 overcast clouds
# 59.7439 10.2045 NO 43.9 73 5 1.45 clear sky
# 24.9 -76.2 BS 84.07 73 0 17.07 clear sky
# -34.5322 20.0403 ZA 50.86 91 0 1.39 clear sky
# 6.8837 116.8477 MY 77.29 94 20 1.14 light rain
# 40.2503 -103.8 US 94.42 9 0 4.61 clear sky
# 66.0449 -17.3389 IS 52.75 82 64 2.95 broken clouds
# -20.4081 57.7 MU 71.26 88 40 11.5 scattered clouds
# City not found. Skipping...
# 21.3469 -158.0858 US 84.56 55 20 16.11 few clouds
# -21.0273 55.539 RE 64.06 97 100 16.11 moderate rain
# 22.0752 -159.319 US 84.18 68 40 12.66 scattered clouds
# 20.7 -105.2 MX 83.43 79 75 10.36 broken clouds
# 47.1666 -55.1483 CA 56.86 100 31 1.01 scattered clouds
# 71.2906 -156.7887 US 37.42 87 20 6.91 few clouds
# -21.3667 55.6167 RE 68.38 84 34 13.56 light rain
# -43.3002 -65.1023 AR 48.49 93 100 8.05 light rain
# -29.9533 -71.3436 CL 60.53 55 0 13.8 clear sky
# -15.1961 12.1522 AO 63 90 11 2.24 few clouds
# -34.5833 150.8552 AU 62.38 84 100 5.01 overcast clouds
# 26.1879 -81.6951 US 86.99 100 100 3.44 light rain
# City not found. Skipping...
# -9.8 -139.0333 PF 76.21 77 37 20.92 light rain
# 63.4427 -20.2734 IS 52.41 93 100 9.8 overcast clouds
# -19.9842 57.6142 MU 71.47 74 5 7 clear sky
# 12.3134 122.0853 PH 79.27 76 100 2.71 overcast clouds
# 61.3614 63.5842 RU 54.32 85 21 8.59 few clouds
# 35.1333 140.3 JP 66.76 85 100 18.45 overcast clouds
# -37.6167 -73.65 CL 49.69 68 53 9.37 broken clouds
# 42.1584 -72.3287 US 74.91 75 75 8.05 broken clouds
# -7.9631 145.7785 PG 77.99 84 46 7.38 scattered clouds
# 5.9485 80.5353 LK 77.2 89 19 9.06 few clouds
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# 20.5022 -10.0711 MR 96.51 16 100 8.7 overcast clouds
# 62.1564 -7.1664 FO 50.92 93 100 10.36 light rain
# 59.3833 143.3 RU 37.71 63 24 13.44 few clouds
# 63.9061 38.1404 RU 47.88 91 100 14.14 overcast clouds
# City not found. Skipping...
# 24.7 -77.7667 BS 84.78 70 1 13.82 clear sky
# -0.8667 134.0833 ID 77.4 81 100 0.65 overcast clouds
# -25.2986 152.8535 AU 67.98 74 33 8.28 scattered clouds
# 57.3064 88.1667 RU 39.02 95 94 3.11 overcast clouds
# 9.2833 79.1167 IN 82.89 77 55 12.33 broken clouds
# 70.6333 147.9167 RU 31.66 93 100 14.43 light snow
# City not found. Skipping...
# -33.0393 -71.6273 CL 59.23 97 40 16.11 scattered clouds
# 9.5334 31.6605 SS 73.72 86 94 1.66 overcast clouds
# 51.226 -58.6502 CA 56.61 52 0 8.03 clear sky
# 54.5392 17.7501 PL 51.93 95 69 5.03 broken clouds
# -35.1 173.7833 NZ 59.32 97 40 5.86 scattered clouds
# 42.097 -79.2353 US 75.02 48 0 11.5 clear sky
# -34.0527 23.3716 ZA 55.69 78 0 6.13 clear sky
# -35.1667 173.1667 NZ 60.06 87 8 4.61 clear sky
# 39.8333 -4 ES 78.31 48 0 1.77 clear sky
# -3.6667 152.4333 PG 77.95 85 100 5.41 moderate rain
# 7.0419 134.2556 PW 75.7 71 100 5.26 overcast clouds
# 69.2167 -51.1 GL 37.42 93 75 8.05 light intensity drizzle rain
# 18.3851 42.4509 SA 64.51 54 96 2.98 overcast clouds
# 55.446 8.3979 DK 49.05 87 5 2.3 clear sky
# 10.3744 10.7288 NG 74.64 87 13 3.6 few clouds
# -22.9661 -42.0278 BR 75.06 69 0 10.36 clear sky
# -23.5333 148.1667 AU 67.33 86 84 16.87 broken clouds
# 55.9667 -4.6333 GB 58.55 76 75 5.75 broken clouds
# 62.456 -114.3525 CA 55.92 50 20 8.05 few clouds
# 68.0531 39.5131 RU 44.6 92 100 25.48 light rain
# -20.2833 44.2833 MG 73.2 75 0 10.78 clear sky
# -35.3333 -72.4167 CL 51.82 63 3 11.97 clear sky
# 18.8731 -71.5166 DO 80.44 77 100 3.65 overcast clouds
# 59.7035 30.7861 RU 49.91 95 74 3.42 broken clouds
# -9.1061 124.8925 ID 72.39 88 36 4.12 scattered clouds
# 2.0167 112.9333 MY 70.84 99 71 1.59 light rain
# -5.1989 -35.4608 BR 76.8 75 23 13.91 few clouds
# -39.9333 175.5667 NZ 54.55 78 57 1.32 broken clouds
# -6.2167 155.6333 PG 79.02 84 99 3.8 light rain
# 69.4865 88.3972 RU 27.21 73 100 9.06 overcast clouds
# 53.0452 158.6483 RU 46.78 81 75 4.47 broken clouds
# City not found. Skipping...
# -38.2667 141.9667 AU 50.97 93 100 7.54 light rain
# 50.1167 139.15 RU 25.95 96 23 4.25 few clouds
# 19.7297 -155.09 US 84.27 57 0 5.99 clear sky
# -16.4833 -151.75 PF 77.86 75 9 16.13 clear sky
# 60.9167 -46.05 GL 44.82 81 13 2.48 few clouds
# -11.0964 -77.6139 PE 64.6 74 23 13.47 few clouds
# 69.7008 170.3133 RU 37.11 61 82 13.2 broken clouds
# 78.2186 15.6401 SJ 35.44 75 75 21.85 broken clouds
# City not found. Skipping...
# 22.8909 -109.9124 MX 85.6 83 100 11.5 overcast clouds
# -25.1132 29.0445 ZA 62.6 83 4 9.93 light rain
# -8.2578 -49.2647 BR 95.5 22 21 3 few clouds
# 70.9821 25.9704 NO 42.55 70 75 8.05 light rain
# 39.8167 98.3 CN 61.99 32 0 7.02 clear sky
# 58.0372 14.9782 SE 38.39 82 43 0.76 scattered clouds
# 57.1437 -2.0981 GB 61.29 85 100 6.91 overcast clouds
# City not found. Skipping...
# 66.6572 66.4183 RU 48.69 97 98 10.25 overcast clouds
# 21.4267 39.8261 SA 85.62 29 3 5.35 clear sky
# -0.9516 122.7875 ID 75.4 88 73 3.98 broken clouds
# 37.7167 -25.4333 PT 77.2 80 92 2.13 overcast clouds
# City not found. Skipping...
# City not found. Skipping...
# 51.2737 15.9366 PL 48.27 85 70 8.86 broken clouds
# 64.1835 -51.7216 GL 39.81 93 75 9.22 broken clouds
# 7.5264 -12.505 SL 76.77 87 100 8.1 light rain
# 18.7369 7.3853 NE 93.67 30 82 7.63 broken clouds
# 69.4058 86.1778 RU 27.63 69 100 11.9 overcast clouds
# 37.4636 -122.4286 US 80.55 61 20 9.22 few clouds
# 30.6945 78.4932 IN 63.03 86 91 3.89 overcast clouds
# 68.75 161.3 RU 38.3 63 100 15.99 light rain
# 57.0531 -135.33 US 57.09 72 75 3.44 broken clouds
# -20.4597 -66.825 BO 52.77 10 0 31.85 clear sky
# 34.5686 105.8933 CN 52.61 92 87 2.53 overcast clouds
# 68.5646 14.9108 NO 48.16 71 100 5.75 overcast clouds
# 65.282 -126.8329 CA 53.64 54 75 8.05 broken clouds
# 10.3999 5.4695 NG 72.27 94 6 2.48 clear sky
# -31.4333 152.9167 AU 56.89 78 100 11.05 moderate rain
# 46.4083 -105.8406 US 61.77 48 0 12.66 clear sky
# 60.0158 41.0614 RU 48 95 100 9.37 overcast clouds
# -41.0667 145.9167 AU 51.94 86 100 7.61 overcast clouds
# 57.79 -152.4072 US 54.91 62 0 12.66 clear sky
# 28.3667 129.4833 JP 68.92 75 3 8.12 clear sky
# 71.9167 114.0833 RU 24.89 87 100 18.72 overcast clouds
# 52.4652 46.6308 RU 55.92 67 52 6.15 broken clouds
# 20 -3 ML 95.31 30 30 7.45 scattered clouds
# 64.8945 -23.7142 IS 50.47 90 89 10.87 overcast clouds
# City not found. Skipping...
# 43.3218 129.7634 CN 37.11 83 0 1.54 clear sky
# 23.4333 84.6833 IN 71.92 98 90 4.88 overcast clouds
# City not found. Skipping...
# 6.8436 101.178 TH 78.55 82 100 7.49 overcast clouds
# 41.2547 67.9692 KZ 70.93 34 0 8.63 clear sky
# 14.3 -91.9167 GT 90.14 75 40 9.19 scattered clouds
# 33.6416 42.8251 IQ 87.21 15 0 3.65 clear sky
# 12.4841 123.3827 PH 79.65 82 100 6.08 overcast clouds
# 42.7762 -9.0603 ES 69.84 81 1 6.69 clear sky
# 65.3667 64.6667 RU 49.77 81 29 17.96 scattered clouds
# 19.05 -95.9833 MX 86.22 75 100 10.18 overcast clouds
# 54.7183 135.315 RU 37.36 73 4 17.92 clear sky
# 62.2266 -6.589 FO 52.72 95 100 10.04 overcast clouds
# City not found. Skipping...
# 20.8947 -156.47 US 87.82 62 20 24.16 few clouds
# 12.35 32.1833 SD 79.65 72 100 5.19 overcast clouds
# -6.1349 12.3689 AO 73.81 87 35 9.08 scattered clouds
# 47.4411 -70.4986 CA 54.99 80 100 4.09 overcast clouds
# 68.3065 -53.4641 GL 37.45 81 100 14.7 overcast clouds
# 62.0989 126.6992 RU 24.75 84 90 5.88 overcast clouds
# -33.8667 121.9 AU 53.46 86 0 12.91 clear sky
# 32.6667 -17.1 PT 75 95 52 3.91 broken clouds
# City not found. Skipping...
# 28.6585 -17.9182 ES 71.35 92 100 6.91 overcast clouds
# 58.8053 -122.7002 CA 54.99 47 75 3.44 broken clouds
# -6.8844 112.2051 ID 77.41 82 100 7.58 overcast clouds
# 37.7667 -25.7 PT 75.24 73 20 4.61 few clouds
# 18.8333 -97.15 MX 73.71 73 100 8.19 overcast clouds
# -13.7 -76.2167 PE 68.05 64 0 18.41 clear sky
# 50.2334 -63.5986 CA 57.56 51 0 9.22 clear sky
# -12.9319 45.1483 YT 75.13 78 24 6.15 few clouds
# 48.9909 29.8047 UA 46.27 93 96 14.38 moderate rain
# 17.4924 44.1277 SA 81.25 34 87 4.74 overcast clouds
# 35.7333 140.8333 JP 63.28 72 100 21.72 overcast clouds
# 10.9995 122.6711 PH 75.88 88 100 2.1 overcast clouds
# -9.1667 -60.6333 BR 90.9 38 75 3.91 broken clouds
# 26.7693 31.5021 EG 80.71 31 0 5.99 clear sky
# 69.6496 18.957 NO 42.82 70 75 13.8 broken clouds
# -17.9333 19.7667 NA 64.06 18 0 7.47 clear sky
# 43.4578 -88.8373 US 78.42 83 0 6.91 clear sky
# 64.7507 20.9528 SE 34.16 100 0 5.75 clear sky
# -26.7852 -60.4388 AR 68.09 73 96 7.96 overcast clouds
# 48.3833 -4.6167 FR 57.25 91 0 6.91 clear sky
# -3.8004 102.2655 ID 74.82 91 100 5.01 overcast clouds
# 64.8378 -147.7164 US 46.36 84 75 5.75 broken clouds
# 50.1001 -91.917 CA 73.47 68 40 10.36 scattered clouds
# 42.975 144.3747 JP 54.23 70 100 4.76 overcast clouds
# 44.7142 43.0008 RU 64.74 65 100 4.43 overcast clouds
# 2.1 99.8333 ID 72.82 99 99 2.26 overcast clouds
# 53.2514 140.1822 RU 32.65 81 3 4.63 clear sky
# 34.6391 -120.4579 US 80.69 71 40 9.22 scattered clouds
# 2.9333 11.9833 CM 67.33 99 100 2.57 overcast clouds
# 11.0297 20.2827 TD 69.31 89 100 3.89 overcast clouds
# City not found. Skipping...
# 10.0761 -83.2895 CR 84.07 69 86 5.06 overcast clouds
# 65.6145 -37.6368 GL 39.36 98 100 5.75 light rain
# 53.1333 132.9 RU 28.2 87 90 3.91 overcast clouds
# 71.9667 102.5 RU 21.81 91 94 6.51 overcast clouds
# -45.8667 -67.5 AR 44.46 100 100 12.66 moderate rain
# -0.6 73.0833 MV 81.52 71 8 4.74 clear sky
# 14.0453 124.1694 PH 77.27 90 100 10.76 overcast clouds
# 54.8831 56.8742 RU 56.59 59 98 2.66 overcast clouds
# 29.3669 -94.9669 US 95.18 61 40 9.22 scattered clouds
# 66.3167 -179.1667 RU 34.83 86 33 7.45 scattered clouds
# City not found. Skipping...
# -31.4707 19.776 ZA 52.43 33 0 5.95 clear sky
# 38.4953 102.1739 CN 61.18 47 35 4.79 scattered clouds
# 63.7506 -68.5145 CA 38.93 93 100 0 overcast clouds
# 23.4833 111.3167 CN 74.8 82 57 2.93 broken clouds
# 69.4541 -133.0374 CA 44.6 87 100 9.22 light rain
# 39.9001 -79.7164 US 80.11 41 13 3 few clouds
# -13.2 49.05 MG 74.3 53 97 6.51 overcast clouds
# 63.8424 -22.4338 IS 51.75 100 40 6.91 scattered clouds
# -0.9492 100.3543 ID 76.42 88 98 3.87 overcast clouds
# 14.8961 -24.4956 CV 79.2 76 26 7.74 scattered clouds
# -25.4 -55.2667 PY 73.13 68 87 1.57 overcast clouds
# City not found. Skipping...
# 41.7911 -107.2387 US 80.49 19 20 18.41 few clouds
# 64.8569 -147.8028 US 46.35 84 75 5.75 broken clouds
# -14.8361 -56.4275 BR 94.95 32 86 5.86 overcast clouds
# 22.5667 59.5289 OM 82.72 69 0 9.48 clear sky
# 29.1911 73.2086 IN 87.67 40 3 10.11 clear sky
# 41.3712 -73.414 US 76.66 61 20 6.91 few clouds
# -30.1811 -50.2056 BR 62.01 86 98 11.52 overcast clouds
# 29.0331 21.5482 LY 87.1 26 0 6.8 clear sky
# -3.3244 114.591 ID 73.54 96 100 2.98 overcast clouds
# 29.1614 16.139 LY 90.99 13 2 7.11 clear sky
# 36.3868 4.3989 DZ 71.13 67 100 5.12 overcast clouds
# 40.5833 -5 ES 68.65 54 4 2.06 clear sky
# 20.4167 72.85 IN 77.5 84 68 5.48 broken clouds
# 5.1544 120.3241 PH 80.92 77 100 3.91 overcast clouds
# 60.3305 11.2616 NO 41.77 89 0 5.75 clear sky
# -20.5167 57.5167 MU 70.18 88 40 11.5 light rain
# 39.2667 141.8833 JP 55.92 75 72 6.46 broken clouds
# City not found. Skipping...
# -6.6447 -51.995 BR 90.43 30 72 1.79 broken clouds
# 38.2779 16.302 IT 67.33 80 55 4.83 broken clouds
# -2.2717 40.902 KE 75.42 79 64 12.77 broken clouds
# 57.4467 97.3217 RU 34.02 87 39 10.92 scattered clouds
# City not found. Skipping...
# 43.5167 -8.1528 ES 68.85 81 0 11.97 clear sky
# 28.4495 -81.4923 US 89.06 75 75 23.02 mist
# 53.6667 124.8 RU 33.94 87 100 0.31 overcast clouds
# 63.9242 127.4739 RU 25.25 78 9 5.79 clear sky
# -28.5708 -70.7581 CL 64.65 33 0 8.61 clear sky
# City not found. Skipping...
# 66.7697 123.3711 RU 28.35 88 89 15.59 overcast clouds
# 31.7333 131.0667 JP 63.09 87 91 4.03 overcast clouds
# 22.2855 114.1577 HK 84.38 83 55 8.01 broken clouds
# City not found. Skipping...
# 64.2539 -15.2082 IS 51.31 99 100 5.75 overcast clouds
# -22.116 14.2845 NA 55.98 70 0 3.76 clear sky
# -25.2406 130.9889 AU 53.85 51 0 9.6 clear sky
# -4.6667 -73.5167 PE 75.27 92 60 8.88 broken clouds
# -0.7193 8.7815 GA 78.76 83 75 12.66 broken clouds
# 59.5714 7.9877 NO 41.58 75 10 4.16 clear sky
# -20.3297 -40.2925 BR 76.95 83 0 18.41 clear sky
# City not found. Skipping...
# City not found. Skipping...
# 62.2248 49.9922 RU 47.95 94 98 11.14 overcast clouds
# 28.017 -97.5169 US 91.49 48 25 13.15 scattered clouds
# -26.6481 15.1594 NA 64.98 35 0 9.48 clear sky
# 48.0056 91.6419 MN 46.6 33 1 1.99 clear sky
# 22.9167 96.5 MM 66.04 98 100 2.26 overcast clouds
# 17.65 83.2667 IN 79.12 94 75 2.3 mist
# City not found. Skipping...
# 63.05 179.3167 RU 43.72 82 100 19.28 overcast clouds
# -43.5333 172.6333 NZ 51.91 86 100 11.5 light rain
# -35.7167 150.1833 AU 56.1 82 100 5.39 overcast clouds
# 52.634 -1.6959 GB 61.02 71 100 2.66 overcast clouds
# -8.145 159.5921 SB 80.51 78 100 4.72 moderate rain
# 23.6333 94.4167 MM 74.62 99 77 0.65 broken clouds
# 39.9523 -75.1638 US 82.29 48 40 16.11 scattered clouds
# -16.7 -151.0167 PF 78.22 74 2 14.94 clear sky
# 60.4667 166.1 RU 48.52 96 100 15.95 moderate rain
# 52.8333 53.4833 RU 64.63 32 99 4.63 overcast clouds
# 65.4167 -52.9 GL 39.6 85 56 6.44 broken clouds
# -16.92 35.262 MW 80.73 32 1 3.02 clear sky
# 46.6166 10.7002 IT 56.28 88 14 5.88 few clouds
# 62.6062 39.8984 RU 47.93 88 97 11.14 overcast clouds
# City not found. Skipping...
# 20.931 -17.0347 MR 75.18 78 8 19.57 clear sky
# 35.174 -2.9287 MA 73.65 88 0 4.61 clear sky
# 20.15 92.9 MM 79.3 84 91 3.91 overcast clouds
# 64.75 177.4833 RU 41 75 20 17 few clouds
# 65.5833 -171 RU 39.34 70 14 5.21 few clouds
# -22.9597 -44.0406 BR 72.46 85 80 2.24 broken clouds
# 40.4272 71.7189 UZ 70.52 43 14 4.61 few clouds
# 65.75 150.85 RU 34.77 98 100 14.92 snow
# -21.05 31.6667 ZW 64.92 80 27 12.68 scattered clouds
# City not found. Skipping...
# 37.5683 126.9778 KR 56.64 85 0 2.3 clear sky
# 45.0205 -93.218 US 93.15 60 0 10.36 clear sky
# 42.8 93.45 CN 66.99 26 1 10.45 clear sky
# City not found. Skipping...
# 33.1222 46.1646 IR 90.52 8 39 7.45 scattered clouds
# 34.9803 -101.9188 US 92.25 33 1 16.37 clear sky
# 17.0151 54.0924 OM 78.89 94 75 5.75 broken clouds
# 50.75 86.15 RU 44.15 81 13 1.79 few clouds
# City not found. Skipping...
# 38.421 -121.4238 US 77.31 61 40 5.99 scattered clouds
# 40.8021 -124.1637 US 75.74 74 23 8.01 few clouds
# 52.6333 126.75 RU 38.35 74 77 5.14 broken clouds
# City not found. Skipping...
# -45.8742 170.5036 NZ 48.79 92 68 6.15 broken clouds
# City not found. Skipping...
# 33.7333 135.9833 JP 64.49 74 99 4.99 overcast clouds
# -29.3353 -49.7269 BR 63.93 83 34 13.8 scattered clouds
# City not found. Skipping...
# 37.8876 58.516 TM 72.9 33 0 4.61 clear sky
# 46.7001 -75.4493 CA 57.78 76 97 4.81 overcast clouds
# 40.8665 -124.0828 US 75.74 73 0 9.22 clear sky
# City not found. Skipping...
# 40.8257 -73.6982 US 80.62 55 75 11.5 broken clouds
# 32.7941 -79.8626 US 91.54 58 40 8.05 scattered clouds
# 66.4167 112.4 RU 25.45 92 100 13.87 overcast clouds
# -23.6752 22.7876 BW 50.67 36 0 8.12 clear sky
# -0.5853 30.2114 UG 61.52 82 45 0.78 scattered clouds
# 61.9247 63.0231 RU 53.01 80 5 10.92 clear sky
# 7.6244 -11.8332 SL 72.64 98 91 3.2 light rain
# 68.7098 -52.8699 GL 35.85 85 100 11.61 overcast clouds
# City not found. Skipping...
# 68.2191 -135.0107 CA 44.6 93 75 2.3 broken clouds
# 39.1834 -84.5333 US 89.78 54 0 3 clear sky
# 50.6996 -127.4199 CA 59.18 72 20 4.61 few clouds
# 58.5169 -117.136 CA 57.31 54 20 5.75 few clouds
# -22.6667 167.4833 NC 73.67 79 0 8.16 clear sky
# 10.2849 22.7882 CF 72.93 90 19 1.92 light rain
# -34.7333 135.8667 AU 55.26 86 71 17.72 broken clouds
# 29.9697 40.2064 SA 83.77 27 0 7.23 clear sky
# -51.6226 -69.2181 AR 46.45 49 0 20.71 clear sky
# 1 -52 BR 79 71 98 8.41 overcast clouds
# 12.485 -16.5469 SN 78.98 96 100 4.74 light rain
# 12.3429 -83.6712 NI 84.29 81 61 1.88 broken clouds
# 41.667 12.5052 IT 70.92 75 40 3.44 scattered clouds
# City not found. Skipping...
# 60.996 24.4643 FI 47.14 86 92 6.17 overcast clouds
# 54.2797 -0.4044 GB 58.91 77 85 1.01 overcast clouds
# 50.6789 156.125 RU 49.48 73 55 15.43 broken clouds
# 27.9769 -114.0611 MX 77.25 62 20 14.52 few clouds
# 9.9833 10.9333 NG 72.48 87 28 2.66 scattered clouds
# 15.2447 105.2291 TH 73.38 94 100 2.26 heavy intensity rain
# -17.2614 27.4618 ZM 79.29 44 54 3.47 broken clouds
# 69.3 139.9 RU 24.82 97 100 4.81 light snow
# -20.7331 -42.0294 BR 74.71 68 84 3.85 broken clouds
# -19.5667 18.1167 NA 49.57 32 0 2.3 clear sky
# -2.0226 147.2712 PG 81.1 78 99 8.12 overcast clouds
# City not found. Skipping...
# 51.7317 7.5923 DE 52.14 80 9 3.44 clear sky
# 45.85 24.1667 RO 48.06 82 40 2.3 scattered clouds
# -6.9811 -34.8339 BR 79.47 77 22 12.06 few clouds
# -13.8833 167.55 VU 80.24 78 77 17.85 broken clouds
# 27.9167 96.1667 IN 74.19 97 99 3.11 moderate rain
# 38.1938 41.4885 TR 71.85 22 78 8.39 light rain
# 47.3073 -122.2284 US 81.12 38 0 11.5 clear sky
# -28.8135 153.2773 AU 61.93 94 100 3.44 mist
# -17.7125 -39.2481 BR 72.19 78 15 8.9 few clouds
# 5.65 36.65 ET 70.27 49 100 2.68 overcast clouds
# 67.4667 78.7 RU 35.37 81 100 23.13 light rain
# 63.4453 120.3167 RU 26.56 80 100 4 overcast clouds
# 54.8833 49.9333 RU 57.06 51 70 0.81 broken clouds
# 46.4333 26.4 RO 45.52 86 15 4.47 few clouds
# 67.45 153.6833 RU 36.64 91 100 20.36 overcast clouds
# 45.4375 40.5756 RU 66.25 78 100 5.35 overcast clouds
# -19.65 17.3333 NA 65.07 17 0 8.25 clear sky
# 16.8634 -99.8901 MX 84.02 74 100 9.22 overcast clouds
# 56.9523 63.2513 RU 59.9 53 98 6.08 overcast clouds
# City not found. Skipping...
# -45.5752 -72.0662 CL 46.35 66 75 6.91 broken clouds
# 51.743 7.1816 DE 52.56 83 19 4.29 few clouds
# 29.5833 -9.5 MA 73.29 58 11 1.77 light rain
# 12.2 79.95 IN 81.43 78 100 12.33 overcast clouds
# 21.6667 81.1 IN 75.56 92 100 7.02 overcast clouds
# -8.11 -42.9444 BR 90.66 27 13 7.81 few clouds
# -20.3428 57.7575 MU 71.22 88 40 11.5 light rain
# 49.0331 -119.4524 CA 70.21 35 0 8.05 clear sky
# -23.7 133.8833 AU 57.22 26 2 5.75 clear sky
# -25.185 27.2665 ZA 61.68 21 33 7.87 scattered clouds
# 28.2333 83.9833 NP 70.54 90 100 3.94 overcast clouds
# 12.2833 -10.9667 ML 74.75 92 100 1.45 overcast clouds
# 57.186 14.04 SE 44.06 85 24 1.01 few clouds
# -41.4122 175.5153 NZ 54.16 74 2 3.06 clear sky
# -20.7333 139.5 AU 69.57 100 40 1.14 scattered clouds
# City not found. Skipping...
# 7.4167 81.8167 LK 79.56 76 10 2.68 clear sky
# 27.9994 120.6668 CN 67.28 77 43 3.98 scattered clouds
# 29.1268 15.9477 LY 90.77 13 2 5.77 clear sky
# 5.3302 103.1408 MY 75.15 94 20 3.44 few clouds
# -22.2763 166.4572 NC 77 99 0 2.66 clear sky
# 11.2833 -15.8333 GW 76.78 87 100 6.64 light rain
# 51.5058 104.1469 RU 47.32 82 100 5.82 overcast clouds
# 51.7102 143.2326 RU 38.16 80 6 11.79 clear sky
# 36.7281 -108.2187 US 85.21 31 0 6.91 clear sky
# -1.95 18.2667 CD 69.48 94 98 3.29 overcast clouds
# -14.4086 -56.4461 BR 90.79 37 84 7.7 moderate rain
# -5.8092 -61.3003 BR 93.15 49 0 5.75 clear sky
# -44.7 169.15 NZ 45.1 93 40 1.12 scattered clouds
# 36.6244 -119.3137 US 83.25 46 40 0 scattered clouds
# 7.2083 79.8358 LK 80.65 89 40 5.75 scattered clouds
# -7.3817 108.2082 ID 70.75 97 100 0.76 overcast clouds
# -2.6741 141.3028 PG 76.68 87 100 4.88 overcast clouds
# City not found. Skipping...
# 22.1965 92.2262 BD 74.08 92 6 2.89 clear sky
# -31.95 141.4333 AU 53.17 90 87 24.49 overcast clouds
# -14.9003 50.2788 MG 67.19 83 19 8.19 light rain
# -20.2333 164.0167 NC 75.09 78 0 11.34 clear sky
# 49.8167 -94.4337 CA 68.97 56 75 15.01 broken clouds
# 20.1986 1.0114 ML 95.02 26 61 11.23 broken clouds
# -2.65 10 GA 75.2 86 100 6.87 overcast clouds
# 25.3667 -107.5167 MX 87.71 84 88 3.78 overcast clouds
# 15.2667 76.4 IN 70.9 85 100 9.62 overcast clouds
# 40.5982 -124.1573 US 73.92 71 32 5.99 scattered clouds
# 17.1561 -89.0714 BZ 89.74 62 20 4.61 few clouds
# 53.3668 -104.0009 CA 57.24 100 100 13.8 overcast clouds
# 48.35 -1.2 FR 57.06 90 60 7.65 broken clouds
# 21.1167 70.1167 IN 78.84 77 8 9.31 clear sky
# 54.7682 -101.865 CA 51.64 93 100 6.91 overcast clouds
# 25.6667 94.5 IN 61.41 99 100 1.63 moderate rain
# 30.9525 118.7553 CN 63.41 80 100 5.06 overcast clouds
# 35.0367 32.4264 CY 78.62 73 39 5.55 scattered clouds
# 16.3333 -15 SN 93.07 43 92 12.84 overcast clouds
# 25.0213 37.2685 SA 80.87 56 0 2.21 clear sky
# 43.2879 -8.3886 ES 69.62 66 0 5.01 clear sky
# 18.8003 110.3967 CN 79.03 82 99 0.92 overcast clouds
# 53.3925 -2.5802 GB 60.91 80 100 5.75 overcast clouds
# City not found. Skipping...
# 6.1241 81.1185 LK 79.34 82 8 16.98 clear sky
# 32.6881 128.8419 JP 70.03 62 84 28.77 broken clouds
# 26.5412 -77.0636 BS 84.6 70 0 11.77 clear sky
# 51.1537 37.8879 RU 53.96 66 100 6.53 overcast clouds
# 45.4612 8.0137 IT 60.3 62 1 5.5 clear sky
# 5.4946 -4.0518 CI 74.05 90 73 4.88 broken clouds
# 25.2631 63.471 PK 79.39 79 55 7.31 broken clouds
# 42.7392 -84.6208 US 73.56 64 0 14.97 clear sky
# 4.1213 43.8894 SO 73.72 72 100 15.77 overcast clouds
# 55.2166 -119.4361 CA 58.35 35 11 5.01 few clouds
# 36.8529 -75.978 US 89.64 50 20 9.22 few clouds
# -7.95 110.2833 ID 75.24 89 100 4.81 overcast clouds
# 63.0128 112.4714 RU 33.37 97 100 10.11 light snow
# -25.1667 45.05 MG 70.57 67 0 6.35 clear sky
# -14.2667 50.1667 MG 67.86 86 21 12.37 light rain
# -45.4167 167.7167 NZ 45.03 90 91 0.78 overcast clouds
# 12.5847 -81.7006 CO 86.02 66 100 6.91 overcast clouds
# -3.9443 119.7848 ID 72.3 96 100 3.15 overcast clouds
# 10.4 79.4833 IN 80.67 84 86 9.62 overcast clouds
# 67.667 12.6934 NO 49.48 67 99 20.38 overcast clouds
# 64.4803 76.6897 RU 48.29 95 100 24.58 light rain
# City not found. Skipping...
# 12.15 -68.2667 BQ 87.78 66 20 5.75 few clouds
# 2.0371 45.3438 SO 77.58 86 76 14.58 broken clouds
# 51.4042 5.7486 NL 51.93 85 11 5.17 few clouds
# City not found. Skipping...
# 36.5281 37.9549 SY 75.76 64 1 14.38 clear sky
# 66.8333 70.8333 RU 50.49 98 100 14.56 light rain
# -34.4833 -54.3333 UY 51.85 77 100 7.76 overcast clouds
# 52.4501 -109.1682 CA 56.25 53 96 13.8 overcast clouds
# -3.6954 128.1814 ID 76.23 16 93 1.41 overcast clouds
# 69.3497 87.7602 RU 26.53 73 100 7.34 overcast clouds
# 64.5011 -165.4064 US 44.17 81 0 8.05 clear sky
# 38.4445 -9.1015 PT 76.66 94 100 6.17 overcast clouds
# 68.5333 146.4167 RU 31.78 98 100 13.49 snow
# -10.6167 150.6667 PG 80.31 85 100 11.05 overcast clouds
# 12.7794 45.0367 YE 89.94 62 60 4.14 broken clouds
# 63.1994 75.4507 RU 52.61 98 100 19.35 light rain
# 55.3053 82.7391 RU 40.62 81 11 3.15 few clouds
# City not found. Skipping...
# 54.7167 158.6167 RU 48.78 77 84 21.94 broken clouds
# -28.7667 114.6 AU 50.41 93 89 8.05 overcast clouds
# -19.0595 -169.9187 NU 71.49 94 75 11.5 broken clouds
# 25.2833 -100.0167 MX 88.99 52 33 6.53 scattered clouds
# 70.3705 31.1107 NO 37.38 87 100 11.5 overcast clouds
# -17.3019 31.3306 ZW 68.81 32 2 1.28 clear sky
# 52.7985 28.0048 BY 47.28 90 76 2.93 broken clouds
# -15.5333 167.1667 VU 80.55 76 31 6.62 scattered clouds
# 60.7161 -135.0538 CA 56.17 63 75 13.8 broken clouds
# 5.3505 48.5268 SO 76.57 90 5 19.13 clear sky
# 51.1501 -108.7514 CA 51.93 51 99 17.63 overcast clouds
# 4.9934 19.9619 CF 71.24 97 100 3.42 overcast clouds
# City not found. Skipping...
# -10.4544 161.9205 SB 79.41 86 100 11.27 overcast clouds
# 15.1718 44.3244 YE 63.54 54 87 3.94 overcast clouds
# 16.5167 -90.6439 MX 90.09 49 72 4.68 broken clouds
# 22.9333 57.5333 OM 83.68 47 15 1.7 few clouds
# -18.0607 13.84 NA 68.4 22 0 2.24 clear sky
# 51.3813 1.3862 GB 61.3 70 99 6.33 overcast clouds
# 15.7432 -96.4661 MX 80.04 84 100 4.9 overcast clouds
# -20.7833 117.1333 AU 68.04 37 0 8.34 clear sky
# -10.1256 -36.1756 BR 73.42 77 0 8.23 clear sky
# 31.3525 27.2453 EG 75.4 73 40 10.36 scattered clouds
# -8.1181 111.8935 ID 73.87 92 100 4.81 overcast clouds
# -11.7022 43.2551 KM 73.71 80 33 1.99 scattered clouds
# 62.8 43.25 RU 46.71 95 100 9.42 light rain
# 69.3143 16.1194 NO 44.58 76 75 11.5 broken clouds
# 13.5828 -2.4216 BF 75.07 89 100 11.41 overcast clouds
# 49.4169 -82.4331 CA 73.4 60 75 13.8 broken clouds
# 49.6334 -105.9845 CA 51.62 54 92 20.71 overcast clouds
# 13.9835 10.2704 NE 71.02 61 99 19.39 moderate rain
# 6.7989 81.4808 LK 75.88 82 9 5.28 clear sky
# -33.295 -66.3356 AR 61.86 31 91 4.36 overcast clouds
# City not found. Skipping...
# 51.35 -0.2 GB 61.7 76 0 1.14 clear sky
# -28.8667 153.05 AU 61.79 85 97 1.3 moderate rain
# -14.97 22.6814 ZM 76.66 46 80 4.14 broken clouds
# 44.1539 -87.5693 US 78.37 85 75 12.66 broken clouds
# 56.2139 87.7472 RU 41.18 93 70 0.22 broken clouds
# 56.206 86.44 RU 42.21 93 94 2.66 overcast clouds
# 4.6833 12.3667 CM 67.55 98 97 0.38 overcast clouds
# -37.8333 140.7667 AU 50.25 99 100 3.53 overcast clouds
# 4.9517 8.322 NG 73.06 96 100 1.66 moderate rain
# 46.3044 16.3378 HR 45.81 73 42 0.51 scattered clouds
# 21.65 -101.5 MX 72.46 39 16 17.78 few clouds
# 65.85 74.4859 RU 46.94 97 100 18.77 light rain
# 29.4608 -95.0513 US 95.16 54 40 6.91 scattered clouds
# 52.8814 20.62 PL 48.42 95 66 8.08 broken clouds
# 24.1447 67.4497 PK 80.67 71 36 12.1 scattered clouds
# 42.25 -2.5 ES 56.98 52 0 5.48 clear sky
# 10.6667 122.95 PH 77.92 89 100 5.64 overcast clouds
# 50.2831 39.2872 RU 55.33 56 84 9.64 broken clouds
# 32.2989 69.5725 PK 74.01 49 0 2.91 clear sky
# 6.3711 126.1689 PH 83.25 71 100 5.21 overcast clouds
# 66.1451 -65.7125 CA 37.4 65 75 11.5 broken clouds
# 6.6221 73.07 MV 80.08 80 91 10 overcast clouds
# 43.0833 0.6667 FR 57.02 54 0 5.59 clear sky
# 55.2834 -114.769 CA 53.58 66 0 6.91 clear sky
# City not found. Skipping...
# 29.2747 82.1838 NP 60.3 96 100 2.51 overcast clouds
# -8.7676 160.7034 SB 77.16 87 99 4.88 light rain
# 40.683 -7.4592 PT 65.93 82 7 3 clear sky
# 46.4856 135.8833 RU 30.18 79 0 5.88 clear sky
# 5.8833 -56.3167 SR 78.35 86 96 9.71 light rain
# 34.1667 77.5833 IN 54.01 41 75 4.7 broken clouds
# 24.8 125.2833 JP 79.86 76 88 26.13 overcast clouds
# 1.4451 125.1824 ID 74.25 80 96 5.97 overcast clouds
# 47.4667 84.8667 KZ 58.23 23 0 7.2 clear sky
# -21.4333 47.0833 MG 55.87 84 100 9.6 overcast clouds
# 19.05 -104.25 MX 80.82 81 100 3.74 overcast clouds
# -14.7972 -57.2881 BR 90.34 43 76 3.38 broken clouds
# 9.0833 6.0167 NG 75.9 86 46 3.11 scattered clouds
# -9.6658 -35.7353 BR 78.24 69 0 9.22 clear sky
# 41.2835 -70.0995 US 66.34 48 100 14.52 overcast clouds
# 12.4497 125.2886 PH 77.14 90 100 5.14 overcast clouds
# -11.3847 43.2844 KM 74.89 80 28 9.17 scattered clouds
# 48.5999 -93.4003 CA 71.06 68 75 6.91 broken clouds
# -25.4 -70.4833 CL 59.38 64 0 7.76 clear sky
# 10.7 -12.25 GN 63.21 93 100 0.74 overcast clouds
# 68.0546 166.4372 RU 34.21 63 100 8.57 overcast clouds
# 64.8989 45.7622 RU 47.28 97 100 5.32 light rain
# 59.6425 -151.5483 US 51.67 82 100 3.44 overcast clouds
# -46.2817 169.8464 NZ 49.48 93 60 2.28 broken clouds
# 18.7333 -103.6833 MX 77.31 93 100 0.72 overcast clouds
# 28.5004 -13.8627 ES 74.95 83 20 9.22 few clouds
# -16.1564 33.5867 MZ 81.72 24 0 1.3 clear sky
# 50.5167 115.1333 RU 46.8 70 100 14 overcast clouds
# 49.8834 -106.5512 CA 52.07 46 100 19.51 overcast clouds
# -1.8283 -44.8683 BR 77.77 80 81 5.21 broken clouds
# 6.3005 -10.7969 LR 78.57 87 100 10.98 light rain
# 9.285 105.7244 VN 77.74 88 100 9.44 overcast clouds
# 1.8639 9.7658 GQ 76.71 85 99 4.05 overcast clouds
# 44.1667 66.75 KZ 72.72 22 0 13.04 clear sky
# -5.5569 -80.8222 PE 74.44 55 92 19.42 overcast clouds
# 16.0678 108.2208 VN 76.98 94 75 4.61 moderate rain
# 42.2506 -75.833 US 71.02 75 100 9.22 overcast clouds
# 60.7522 -137.5108 CA 62.55 45 100 3.44 overcast clouds
# -8.0089 -34.8553 BR 80.33 61 20 5.75 few clouds
# 22.6783 -3.9836 ML 100.63 11 1 9.04 clear sky
# 44.5086 50.263 KZ 75.61 35 0 8.1 clear sky
# -17.0822 -40.9358 BR 80.46 46 9 6.13 clear sky
# 32.2994 -9.2372 MA 71.85 83 0 7.45 clear sky
# City not found. Skipping...
# 36.7202 -4.4203 ES 74.73 80 20 1.14 few clouds
# 48.6499 -53.1147 CA 51.8 65 0 8.43 clear sky
# -16.7686 -47.6136 BR 75.02 50 81 2.1 broken clouds
# -8.345 113.6058 ID 74.26 89 100 3.33 moderate rain
# -10.1667 123.5833 ID 76.5 84 64 5.84 broken clouds
# -35.3378 143.5544 AU 51.64 97 100 15.93 overcast clouds
# -9.4431 147.1797 PG 76.42 94 20 5.75 few clouds
# City not found. Skipping...
# 60.8156 -115.7999 CA 62.56 39 40 6.91 scattered clouds
# 25.9018 -97.4975 US 91.4 65 0 5.75 clear sky
# 47.3199 9.5661 CH 52.61 81 100 1.14 overcast clouds
# -9.0763 143.2092 PG 79.43 87 91 14.94 overcast clouds
# 71.0357 27.8492 NO 42.75 70 75 5.75 broken clouds
# 38.6979 -9.4215 PT 76.86 85 20 18.01 few clouds
# 14.9215 -23.5087 CV 79.34 78 20 13.8 few clouds
# 18.451 -78.1736 JM 87.66 69 7 9.28 clear sky
# City not found. Skipping...
# 54.6012 86.2459 RU 45.32 82 95 0.78 overcast clouds
# 37.9281 102.6414 CN 60.53 54 91 2.06 overcast clouds
# -25.9653 32.5892 MZ 63.23 82 75 17.27 drizzle
# -34.0033 24.7314 ZA 53.89 85 0 5.19 clear sky
# 70.8578 29.0864 NO 42.8 81 75 14.97 broken clouds
# 32.8663 59.2211 IR 63.07 22 0 6.91 clear sky
# 20.8624 92.3058 BD 77.14 91 33 6.58 scattered clouds
# -2.9248 -39.9167 BR 77.79 84 67 17.6 broken clouds
# 65.9939 57.5281 RU 49.48 90 100 21.43 light rain
# 19.75 10.25 NE 90.1 9 0 12.01 clear sky
# -23.0067 -44.3181 BR 68.59 86 66 1.83 broken clouds
# 16.5167 -98.75 MX 81.48 84 100 8.32 overcast clouds
# 19.9711 -96.6114 MX 81.54 77 86 8.88 overcast clouds
# 45.0503 136.6092 RU 42.57 59 0 6.67 clear sky
# City not found. Skipping...
# -2.95 25.95 CD 71.24 84 43 0.96 scattered clouds
# 26.326 43.975 SA 91.85 18 56 13.18 broken clouds
# 19.2833 -81.25 KY 86 72 40 3.44 scattered clouds
# -1.195 -46.02 BR 79.25 79 70 7.61 broken clouds
# 36.8 21.95 GR 69.51 77 0 6.26 clear sky
# 20.0058 110.3542 CN 75.18 100 0 0 clear sky
# -3.3667 135.4833 ID 74.62 91 100 3.8 overcast clouds
# 34.0372 -4.9998 MA 77.25 69 75 8.05 thunderstorm with rain
# 7.1333 40.7 ET 64.36 59 100 1.97 overcast clouds
# 20.5083 -86.9458 MX 89.01 74 11 5.99 few clouds
# 39.5108 54.3671 TM 80.76 17 0 8.43 clear sky
# City not found. Skipping...
# 0.6 -80.0333 EC 76.42 79 88 11.48 overcast clouds
# 52.5369 62.4936 KZ 60.76 22 0 5.66 clear sky
# 51.2234 2.9119 BE 57.09 72 75 5.75 broken clouds
# 59.4894 8.634 NO 42.4 79 7 3.24 clear sky
# 20.5169 -13.0499 MR 93.2 27 42 16.2 scattered clouds
# -29.6842 -53.8069 BR 70.9 56 0 8.05 clear sky
# 37.7333 -25.6667 PT 77.5 78 20 3.44 few clouds
# 37.3394 -121.895 US 80.58 41 75 8.01 broken clouds
# 28.8184 115.4327 CN 67.51 60 95 6.51 overcast clouds
# 43.9098 67.2495 KZ 73.87 21 0 14.29 clear sky
# 50.3734 129.1139 RU 41.32 58 100 12.35 overcast clouds
# 41.7057 -70.2286 US 66.34 83 100 8.05 overcast clouds
# City not found. Skipping...
# 42.9744 140.5089 JP 49.42 69 58 3.27 broken clouds
# 9.4942 50.8122 SO 78.39 85 52 19.44 broken clouds
# 52.3668 -114.9188 CA 53.71 40 6 6.91 clear sky
# 34.6667 138.95 JP 63.1 87 100 15.19 overcast clouds
# 52.6333 29.7333 BY 46.29 88 99 4.12 overcast clouds
# 37.3131 40.7436 TR 78.08 16 64 8.79 broken clouds
# 31.953 12.0261 LY 77.61 34 2 3.42 clear sky
# 10.7 37.2667 ET 58.15 98 100 3 moderate rain
# City not found. Skipping...
# 51.5223 59.9396 RU 60.46 21 0 6.42 clear sky
# -23.9045 29.4688 ZA 57.02 90 57 8.23 moderate rain
# 69.2296 17.9811 NO 41.61 77 94 4.38 overcast clouds
# 45.6216 -94.2069 US 87.19 67 100 1.01 overcast clouds
# 48.9723 140.2878 RU 39.43 63 2 8.7 clear sky
# -4.352 152.2633 PG 76.06 84 100 3.67 light rain
# 38.1973 44.7653 IR 68.25 18 35 5.84 scattered clouds
# 0.5333 72.9333 MV 80.42 76 17 4.97 few clouds
# 13.4667 22.2 TD 78.73 58 87 3.15 overcast clouds
# -11.3 35.0333 TZ 64.42 64 2 6.26 clear sky
# 6.7533 -11.3686 LR 77.18 86 99 11.77 light rain
# 11.2408 -74.199 CO 86.9 74 75 12.66 light intensity drizzle
# 46.9167 3.3333 FR 49.69 67 99 4.52 overcast clouds
# 55.9299 39.6144 RU 46.44 89 55 2.53 broken clouds
# 51.3223 42.7678 RU 53.71 58 97 6.62 overcast clouds
# 50.6309 38.6903 RU 55.8 61 100 8.25 overcast clouds
# 28.2167 -106.5833 MX 77.85 46 60 12.26 broken clouds
# 8.9242 -67.4293 VE 85.28 70 81 4.34 broken clouds
# 50.7833 121.5167 CN 41.43 75 100 4.76 overcast clouds
# -2.635 115.2274 ID 71.82 99 100 1.9 overcast clouds
# -33.3833 148.0167 AU 61.92 64 100 8.97 moderate rain
# 51.3674 110.4676 RU 42.37 85 100 11.52 overcast clouds
# City not found. Skipping...
# 62.2167 135.8 RU 24.71 74 5 3.27 clear sky
# 14.2 24.6667 SD 76.3 53 52 5.46 broken clouds
# 9.9287 -69.6201 VE 83.37 64 99 1.86 overcast clouds
# 50.4712 28.8253 UA 47.64 94 100 9.4 overcast clouds
# 10.9639 -74.7964 CO 80.38 83 75 9.22 broken clouds
# 27.85 -105.4833 MX 84.79 36 65 9.42 broken clouds
# 4.05 38.3 ET 63.84 55 100 10.42 overcast clouds
# 15.85 -97.0667 MX 80.74 83 100 5.66 overcast clouds
# 62.1215 39.3192 RU 46.38 94 100 7.78 overcast clouds
# 5.1409 10.5198 CM 61.05 97 85 2.95 overcast clouds
# 0.0847 -76.8828 EC 89.62 51 75 8.05 broken clouds
# 39.8532 3.1214 ES 75.25 63 9 3.89 clear sky
# 52.7055 81.6244 RU 53.71 69 68 6.35 broken clouds
# 19.2056 -69.3369 DO 86.22 79 40 11.5 scattered clouds
# 27.0377 14.4283 LY 89.69 12 0 7.31 clear sky
# -14.8333 -64.9 BO 98.58 41 20 14.97 smoke
# 48.0457 -65.4926 CA 55.98 71 100 4.61 light rain
# 53.858 120.875 RU 32.7 94 43 1.59 scattered clouds
# 13.9216 44.1467 YE 65.64 58 99 5.88 overcast clouds
# 55.1667 124.7167 RU 31.19 94 92 1.07 overcast clouds

# %%
city_data
# Out:
# [{'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 63.91,
#   'Humidity': 59,
#   'Cloudiness': 96,
#   'Wind Speed': 12.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 46.47,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 0.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hokitika',
#   'Country': 'NZ',
#   'Lat': -42.7167,
#   'Lng': 170.9667,
#   'Max Temp': 53.55,
#   'Humidity': 75,
#   'Cloudiness': 80,
#   'Wind Speed': 3.15,
#   'Current Description': 'broken clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 39.36,
#   'Humidity': 100,
#   'Cloudiness': 53,
#   'Wind Speed': 4,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 73.96,
#   'Humidity': 82,
#   'Cloudiness': 18,
#   'Wind Speed': 5.77,
#   'Current Description': 'few clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 58.62,
#   'Humidity': 75,
#   'Cloudiness': 10,
#   'Wind Speed': 9.31,
#   'Current Description': 'clear sky'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 53.73,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 10.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 46.8,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.42,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 32.23,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'snow'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 64.38,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 33.1,
#   'Humidity': 75,
#   'Cloudiness': 6,
#   'Wind Speed': 13.67,
#   'Current Description': 'clear sky'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 49.66,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 75.36,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Xai-Xai',
#   'Country': 'MZ',
#   'Lat': -25.0519,
#   'Lng': 33.6442,
#   'Max Temp': 67.06,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 14.12,
#   'Current Description': 'moderate rain'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 69.39,
#   'Humidity': 87,
#   'Cloudiness': 67,
#   'Wind Speed': 14.79,
#   'Current Description': 'light rain'},
#  {'City': 'Balangiga',
#   'Country': 'PH',
#   'Lat': 11.1097,
#   'Lng': 125.3875,
#   'Max Temp': 78.42,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 57.94,
#   'Humidity': 71,
#   'Cloudiness': 3,
#   'Wind Speed': 16.62,
#   'Current Description': 'clear sky'},
#  {'City': 'Krasnoselkup',
#   'Country': 'RU',
#   'Lat': 65.7,
#   'Lng': 82.4667,
#   'Max Temp': 36.37,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 18.88,
#   'Current Description': 'light rain'},
#  {'City': 'Nueve De Julio',
#   'Country': 'AR',
#   'Lat': -35.4444,
#   'Lng': -60.8831,
#   'Max Temp': 57.96,
#   'Humidity': 41,
#   'Cloudiness': 99,
#   'Wind Speed': 4,
#   'Current Description': 'light rain'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 53.62,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 30.42,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 19.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tourlaville',
#   'Country': 'FR',
#   'Lat': 49.6383,
#   'Lng': -1.5664,
#   'Max Temp': 51.22,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Shaunavon',
#   'Country': 'CA',
#   'Lat': 49.6501,
#   'Lng': -108.4181,
#   'Max Temp': 53.38,
#   'Humidity': 46,
#   'Cloudiness': 50,
#   'Wind Speed': 18.37,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ballina',
#   'Country': 'AU',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp': 62.02,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 7.29,
#   'Current Description': 'light rain'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 81.55,
#   'Humidity': 77,
#   'Cloudiness': 93,
#   'Wind Speed': 9.42,
#   'Current Description': 'light rain'},
#  {'City': 'Kwinana',
#   'Country': 'AU',
#   'Lat': -32.25,
#   'Lng': 115.7667,
#   'Max Temp': 54.34,
#   'Humidity': 75,
#   'Cloudiness': 2,
#   'Wind Speed': 12.84,
#   'Current Description': 'clear sky'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 53.46,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 73.45,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 91.99,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Erzin',
#   'Country': 'TR',
#   'Lat': 36.9559,
#   'Lng': 36.2,
#   'Max Temp': 73.67,
#   'Humidity': 88,
#   'Cloudiness': 39,
#   'Wind Speed': 2.46,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 75.16,
#   'Humidity': 91,
#   'Cloudiness': 67,
#   'Wind Speed': 11.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 73.17,
#   'Humidity': 75,
#   'Cloudiness': 42,
#   'Wind Speed': 1.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 56.1,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81,
#   'Humidity': 76,
#   'Cloudiness': 95,
#   'Wind Speed': 11.92,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qena',
#   'Country': 'EG',
#   'Lat': 26.1615,
#   'Lng': 32.7183,
#   'Max Temp': 81.61,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 8.84,
#   'Current Description': 'clear sky'},
#  {'City': 'Vila Do Maio',
#   'Country': 'CV',
#   'Lat': 15.1333,
#   'Lng': -23.2167,
#   'Max Temp': 79.59,
#   'Humidity': 76,
#   'Cloudiness': 34,
#   'Wind Speed': 13.94,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cayenne',
#   'Country': 'GF',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 77.04,
#   'Humidity': 83,
#   'Cloudiness': 37,
#   'Wind Speed': 5.75,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 73.15,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 16.04,
#   'Current Description': 'clear sky'},
#  {'City': 'Marawi',
#   'Country': 'PH',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 69.26,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.68,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sibolga',
#   'Country': 'ID',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 76.1,
#   'Humidity': 85,
#   'Cloudiness': 84,
#   'Wind Speed': 3.15,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kasimov',
#   'Country': 'RU',
#   'Lat': 54.9411,
#   'Lng': 41.3953,
#   'Max Temp': 48.22,
#   'Humidity': 78,
#   'Cloudiness': 61,
#   'Wind Speed': 2.46,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bud',
#   'Country': 'US',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 90.68,
#   'Humidity': 68,
#   'Cloudiness': 11,
#   'Wind Speed': 5.46,
#   'Current Description': 'few clouds'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 59.14,
#   'Humidity': 87,
#   'Cloudiness': 32,
#   'Wind Speed': 3.22,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mangan',
#   'Country': 'IN',
#   'Lat': 27.5167,
#   'Lng': 88.5333,
#   'Max Temp': 73.42,
#   'Humidity': 91,
#   'Cloudiness': 91,
#   'Wind Speed': 1.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Johnson City',
#   'Country': 'US',
#   'Lat': 36.3134,
#   'Lng': -82.3535,
#   'Max Temp': 88.12,
#   'Humidity': 52,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 44.76,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 55.45,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 10.13,
#   'Current Description': 'clear sky'},
#  {'City': 'Mackay',
#   'Country': 'AU',
#   'Lat': -21.15,
#   'Lng': 149.2,
#   'Max Temp': 72.68,
#   'Humidity': 81,
#   'Cloudiness': 63,
#   'Wind Speed': 7.72,
#   'Current Description': 'broken clouds'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 33.39,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.31,
#   'Current Description': 'light snow'},
#  {'City': 'San Quintin',
#   'Country': 'MX',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 74.53,
#   'Humidity': 66,
#   'Cloudiness': 77,
#   'Wind Speed': 15.52,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 53.8,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 9.28,
#   'Current Description': 'clear sky'},
#  {'City': 'Chama',
#   'Country': 'CH',
#   'Lat': 47.1821,
#   'Lng': 8.4636,
#   'Max Temp': 53.82,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Current Description': 'broken clouds'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 54.27,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Current Description': 'few clouds'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 41.4,
#   'Humidity': 90,
#   'Cloudiness': 21,
#   'Wind Speed': 11.21,
#   'Current Description': 'few clouds'},
#  {'City': 'Road Town',
#   'Country': 'VG',
#   'Lat': 18.4167,
#   'Lng': -64.6167,
#   'Max Temp': 87.89,
#   'Humidity': 84,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 64.06,
#   'Humidity': 76,
#   'Cloudiness': 53,
#   'Wind Speed': 3.13,
#   'Current Description': 'broken clouds'},
#  {'City': 'Qaqortoq',
#   'Country': 'GL',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 42.78,
#   'Humidity': 85,
#   'Cloudiness': 12,
#   'Wind Speed': 3.4,
#   'Current Description': 'few clouds'},
#  {'City': 'Arman',
#   'Country': 'RU',
#   'Lat': 59.7,
#   'Lng': 150.1667,
#   'Max Temp': 41.02,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Minudasht',
#   'Country': 'IR',
#   'Lat': 37.2289,
#   'Lng': 55.3747,
#   'Max Temp': 71.92,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 3.76,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Augusta',
#   'Country': 'AU',
#   'Lat': -32.5,
#   'Lng': 137.7667,
#   'Max Temp': 56.82,
#   'Humidity': 86,
#   'Cloudiness': 74,
#   'Wind Speed': 17.25,
#   'Current Description': 'broken clouds'},
#  {'City': 'Liverpool',
#   'Country': 'GB',
#   'Lat': 53.4106,
#   'Lng': -2.9779,
#   'Max Temp': 60.75,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 78.73,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nelson Bay',
#   'Country': 'AU',
#   'Lat': -32.7167,
#   'Lng': 152.15,
#   'Max Temp': 64,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 10,
#   'Current Description': 'light rain'},
#  {'City': 'Portland',
#   'Country': 'US',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 85.68,
#   'Humidity': 26,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Description': 'few clouds'},
#  {'City': 'Elizabeth City',
#   'Country': 'US',
#   'Lat': 36.2946,
#   'Lng': -76.2511,
#   'Max Temp': 90.01,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 24.33,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 6.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Agapovka',
#   'Country': 'RU',
#   'Lat': 53.2973,
#   'Lng': 59.1348,
#   'Max Temp': 54.61,
#   'Humidity': 33,
#   'Cloudiness': 77,
#   'Wind Speed': 4.27,
#   'Current Description': 'broken clouds'},
#  {'City': 'Meulaboh',
#   'Country': 'ID',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 75.78,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 31.98,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 10.87,
#   'Current Description': 'light snow'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 59.58,
#   'Humidity': 71,
#   'Cloudiness': 38,
#   'Wind Speed': 7.11,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kaduqli',
#   'Country': 'SD',
#   'Lat': 11.0167,
#   'Lng': 29.7167,
#   'Max Temp': 74.59,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 1.77,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 78.98,
#   'Humidity': 54,
#   'Cloudiness': 67,
#   'Wind Speed': 2.19,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ancud',
#   'Country': 'CL',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 47.23,
#   'Humidity': 77,
#   'Cloudiness': 42,
#   'Wind Speed': 5.1,
#   'Current Description': 'light rain'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 55.51,
#   'Humidity': 35,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Uruzgan',
#   'Country': 'AF',
#   'Lat': 32.8333,
#   'Lng': 66,
#   'Max Temp': 67.46,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 2.37,
#   'Current Description': 'clear sky'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 53.1,
#   'Humidity': 66,
#   'Cloudiness': 89,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ternate',
#   'Country': 'ID',
#   'Lat': 0.8,
#   'Lng': 127.4,
#   'Max Temp': 79.9,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 1.66,
#   'Current Description': 'moderate rain'},
#  {'City': 'Nioro',
#   'Country': 'GM',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 74.14,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 75.6,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Ust-Kulom',
#   'Country': 'RU',
#   'Lat': 61.6864,
#   'Lng': 53.6902,
#   'Max Temp': 53.06,
#   'Humidity': 72,
#   'Cloudiness': 76,
#   'Wind Speed': 13.85,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 49.35,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 0.83,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Drammen',
#   'Country': 'NO',
#   'Lat': 59.7439,
#   'Lng': 10.2045,
#   'Max Temp': 43.9,
#   'Humidity': 73,
#   'Cloudiness': 5,
#   'Wind Speed': 1.45,
#   'Current Description': 'clear sky'},
#  {'City': 'Rock Sound',
#   'Country': 'BS',
#   'Lat': 24.9,
#   'Lng': -76.2,
#   'Max Temp': 84.07,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 17.07,
#   'Current Description': 'clear sky'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 50.86,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 1.39,
#   'Current Description': 'clear sky'},
#  {'City': 'Kudat',
#   'Country': 'MY',
#   'Lat': 6.8837,
#   'Lng': 116.8477,
#   'Max Temp': 77.29,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 1.14,
#   'Current Description': 'light rain'},
#  {'City': 'Fort Morgan',
#   'Country': 'US',
#   'Lat': 40.2503,
#   'Lng': -103.8,
#   'Max Temp': 94.42,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Husavik',
#   'Country': 'IS',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 52.75,
#   'Humidity': 82,
#   'Cloudiness': 64,
#   'Wind Speed': 2.95,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 71.26,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Makakilo City',
#   'Country': 'US',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 84.56,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Current Description': 'few clouds'},
#  {'City': 'Salazie',
#   'Country': 'RE',
#   'Lat': -21.0273,
#   'Lng': 55.539,
#   'Max Temp': 64.06,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Current Description': 'moderate rain'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 84.18,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ixtapa',
#   'Country': 'MX',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 83.43,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Marystown',
#   'Country': 'CA',
#   'Lat': 47.1666,
#   'Lng': -55.1483,
#   'Max Temp': 56.86,
#   'Humidity': 100,
#   'Cloudiness': 31,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 37.42,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Current Description': 'few clouds'},
#  {'City': 'Saint-Joseph',
#   'Country': 'RE',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 68.38,
#   'Humidity': 84,
#   'Cloudiness': 34,
#   'Wind Speed': 13.56,
#   'Current Description': 'light rain'},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 48.49,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Current Description': 'light rain'},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 60.53,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Namibe',
#   'Country': 'AO',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 63,
#   'Humidity': 90,
#   'Cloudiness': 11,
#   'Wind Speed': 2.24,
#   'Current Description': 'few clouds'},
#  {'City': 'Flinders',
#   'Country': 'AU',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 62.38,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Golden Gate',
#   'Country': 'US',
#   'Lat': 26.1879,
#   'Lng': -81.6951,
#   'Max Temp': 86.99,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Current Description': 'light rain'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 76.21,
#   'Humidity': 77,
#   'Cloudiness': 37,
#   'Wind Speed': 20.92,
#   'Current Description': 'light rain'},
#  {'City': 'Vestmannaeyjar',
#   'Country': 'IS',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 52.41,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 9.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cap Malheureux',
#   'Country': 'MU',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 71.47,
#   'Humidity': 74,
#   'Cloudiness': 5,
#   'Wind Speed': 7,
#   'Current Description': 'clear sky'},
#  {'City': 'Tugdan',
#   'Country': 'PH',
#   'Lat': 12.3134,
#   'Lng': 122.0853,
#   'Max Temp': 79.27,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 2.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sovetskiy',
#   'Country': 'RU',
#   'Lat': 61.3614,
#   'Lng': 63.5842,
#   'Max Temp': 54.32,
#   'Humidity': 85,
#   'Cloudiness': 21,
#   'Wind Speed': 8.59,
#   'Current Description': 'few clouds'},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 66.76,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 18.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 49.69,
#   'Humidity': 68,
#   'Cloudiness': 53,
#   'Wind Speed': 9.37,
#   'Current Description': 'broken clouds'},
#  {'City': 'Palmer',
#   'Country': 'US',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 74.91,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kerema',
#   'Country': 'PG',
#   'Lat': -7.9631,
#   'Lng': 145.7785,
#   'Max Temp': 77.99,
#   'Humidity': 84,
#   'Cloudiness': 46,
#   'Wind Speed': 7.38,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Matara',
#   'Country': 'LK',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 77.2,
#   'Humidity': 89,
#   'Cloudiness': 19,
#   'Wind Speed': 9.06,
#   'Current Description': 'few clouds'},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 96.51,
#   'Humidity': 16,
#   'Cloudiness': 100,
#   'Wind Speed': 8.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vestmanna',
#   'Country': 'FO',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 50.92,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Current Description': 'light rain'},
#  {'City': 'Okhotsk',
#   'Country': 'RU',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 37.71,
#   'Humidity': 63,
#   'Cloudiness': 24,
#   'Wind Speed': 13.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Onega',
#   'Country': 'RU',
#   'Lat': 63.9061,
#   'Lng': 38.1404,
#   'Max Temp': 47.88,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 14.14,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Andros Town',
#   'Country': 'BS',
#   'Lat': 24.7,
#   'Lng': -77.7667,
#   'Max Temp': 84.78,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 13.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Manokwari',
#   'Country': 'ID',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 77.4,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 0.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hervey Bay',
#   'Country': 'AU',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 67.98,
#   'Humidity': 74,
#   'Cloudiness': 33,
#   'Wind Speed': 8.28,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Teguldet',
#   'Country': 'RU',
#   'Lat': 57.3064,
#   'Lng': 88.1667,
#   'Max Temp': 39.02,
#   'Humidity': 95,
#   'Cloudiness': 94,
#   'Wind Speed': 3.11,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mandapam',
#   'Country': 'IN',
#   'Lat': 9.2833,
#   'Lng': 79.1167,
#   'Max Temp': 82.89,
#   'Humidity': 77,
#   'Cloudiness': 55,
#   'Wind Speed': 12.33,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 31.66,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 14.43,
#   'Current Description': 'light snow'},
#  {'City': 'Valparaiso',
#   'Country': 'CL',
#   'Lat': -33.0393,
#   'Lng': -71.6273,
#   'Max Temp': 59.23,
#   'Humidity': 97,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Malakal',
#   'Country': 'SS',
#   'Lat': 9.5334,
#   'Lng': 31.6605,
#   'Max Temp': 73.72,
#   'Humidity': 86,
#   'Cloudiness': 94,
#   'Wind Speed': 1.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Augustin',
#   'Country': 'CA',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 56.61,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 8.03,
#   'Current Description': 'clear sky'},
#  {'City': 'Lebork',
#   'Country': 'PL',
#   'Lat': 54.5392,
#   'Lng': 17.7501,
#   'Max Temp': 51.93,
#   'Humidity': 95,
#   'Cloudiness': 69,
#   'Wind Speed': 5.03,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kaeo',
#   'Country': 'NZ',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 59.32,
#   'Humidity': 97,
#   'Cloudiness': 40,
#   'Wind Speed': 5.86,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 75.02,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Plettenberg Bay',
#   'Country': 'ZA',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 55.69,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 6.13,
#   'Current Description': 'clear sky'},
#  {'City': 'Ahipara',
#   'Country': 'NZ',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 60.06,
#   'Humidity': 87,
#   'Cloudiness': 8,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Toledo',
#   'Country': 'ES',
#   'Lat': 39.8333,
#   'Lng': -4,
#   'Max Temp': 78.31,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 1.77,
#   'Current Description': 'clear sky'},
#  {'City': 'Namatanai',
#   'Country': 'PG',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 77.95,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.41,
#   'Current Description': 'moderate rain'},
#  {'City': 'Kloulklubed',
#   'Country': 'PW',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 75.7,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 5.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 37.42,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'light intensity drizzle rain'},
#  {'City': 'Faya',
#   'Country': 'SA',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 64.51,
#   'Humidity': 54,
#   'Cloudiness': 96,
#   'Wind Speed': 2.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nordby',
#   'Country': 'DK',
#   'Lat': 55.446,
#   'Lng': 8.3979,
#   'Max Temp': 49.05,
#   'Humidity': 87,
#   'Cloudiness': 5,
#   'Wind Speed': 2.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Bara',
#   'Country': 'NG',
#   'Lat': 10.3744,
#   'Lng': 10.7288,
#   'Max Temp': 74.64,
#   'Humidity': 87,
#   'Cloudiness': 13,
#   'Wind Speed': 3.6,
#   'Current Description': 'few clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 75.06,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Emerald',
#   'Country': 'AU',
#   'Lat': -23.5333,
#   'Lng': 148.1667,
#   'Max Temp': 67.33,
#   'Humidity': 86,
#   'Cloudiness': 84,
#   'Wind Speed': 16.87,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cardross',
#   'Country': 'GB',
#   'Lat': 55.9667,
#   'Lng': -4.6333,
#   'Max Temp': 58.55,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 55.92,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Description': 'few clouds'},
#  {'City': 'Ostrovnoy',
#   'Country': 'RU',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 44.6,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 25.48,
#   'Current Description': 'light rain'},
#  {'City': 'Morondava',
#   'Country': 'MG',
#   'Lat': -20.2833,
#   'Lng': 44.2833,
#   'Max Temp': 73.2,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 10.78,
#   'Current Description': 'clear sky'},
#  {'City': 'Constitucion',
#   'Country': 'CL',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 51.82,
#   'Humidity': 63,
#   'Cloudiness': 3,
#   'Wind Speed': 11.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Las Matas De Farfan',
#   'Country': 'DO',
#   'Lat': 18.8731,
#   'Lng': -71.5166,
#   'Max Temp': 80.44,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 3.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 49.91,
#   'Humidity': 95,
#   'Cloudiness': 74,
#   'Wind Speed': 3.42,
#   'Current Description': 'broken clouds'},
#  {'City': 'Atambua',
#   'Country': 'ID',
#   'Lat': -9.1061,
#   'Lng': 124.8925,
#   'Max Temp': 72.39,
#   'Humidity': 88,
#   'Cloudiness': 36,
#   'Wind Speed': 4.12,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kapit',
#   'Country': 'MY',
#   'Lat': 2.0167,
#   'Lng': 112.9333,
#   'Max Temp': 70.84,
#   'Humidity': 99,
#   'Cloudiness': 71,
#   'Wind Speed': 1.59,
#   'Current Description': 'light rain'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 76.8,
#   'Humidity': 75,
#   'Cloudiness': 23,
#   'Wind Speed': 13.91,
#   'Current Description': 'few clouds'},
#  {'City': 'Hunterville',
#   'Country': 'NZ',
#   'Lat': -39.9333,
#   'Lng': 175.5667,
#   'Max Temp': 54.55,
#   'Humidity': 78,
#   'Cloudiness': 57,
#   'Wind Speed': 1.32,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kieta',
#   'Country': 'PG',
#   'Lat': -6.2167,
#   'Lng': 155.6333,
#   'Max Temp': 79.02,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 3.8,
#   'Current Description': 'light rain'},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 27.21,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 9.06,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Country': 'RU',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 46.78,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 4.47,
#   'Current Description': 'broken clouds'},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 50.97,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.54,
#   'Current Description': 'light rain'},
#  {'City': 'Vysokogornyy',
#   'Country': 'RU',
#   'Lat': 50.1167,
#   'Lng': 139.15,
#   'Max Temp': 25.95,
#   'Humidity': 96,
#   'Cloudiness': 23,
#   'Wind Speed': 4.25,
#   'Current Description': 'few clouds'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 84.27,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 77.86,
#   'Humidity': 75,
#   'Cloudiness': 9,
#   'Wind Speed': 16.13,
#   'Current Description': 'clear sky'},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 44.82,
#   'Humidity': 81,
#   'Cloudiness': 13,
#   'Wind Speed': 2.48,
#   'Current Description': 'few clouds'},
#  {'City': 'Hualmay',
#   'Country': 'PE',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 64.6,
#   'Humidity': 74,
#   'Cloudiness': 23,
#   'Wind Speed': 13.47,
#   'Current Description': 'few clouds'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 37.11,
#   'Humidity': 61,
#   'Cloudiness': 82,
#   'Wind Speed': 13.2,
#   'Current Description': 'broken clouds'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 35.44,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 21.85,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 85.6,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Siyabuswa',
#   'Country': 'ZA',
#   'Lat': -25.1132,
#   'Lng': 29.0445,
#   'Max Temp': 62.6,
#   'Humidity': 83,
#   'Cloudiness': 4,
#   'Wind Speed': 9.93,
#   'Current Description': 'light rain'},
#  {'City': 'Conceicao Do Araguaia',
#   'Country': 'BR',
#   'Lat': -8.2578,
#   'Lng': -49.2647,
#   'Max Temp': 95.5,
#   'Humidity': 22,
#   'Cloudiness': 21,
#   'Wind Speed': 3,
#   'Current Description': 'few clouds'},
#  {'City': 'Honningsvag',
#   'Country': 'NO',
#   'Lat': 70.9821,
#   'Lng': 25.9704,
#   'Max Temp': 42.55,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'light rain'},
#  {'City': 'Jiayuguan',
#   'Country': 'CN',
#   'Lat': 39.8167,
#   'Lng': 98.3,
#   'Max Temp': 61.99,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 7.02,
#   'Current Description': 'clear sky'},
#  {'City': 'Tranas',
#   'Country': 'SE',
#   'Lat': 58.0372,
#   'Lng': 14.9782,
#   'Max Temp': 38.39,
#   'Humidity': 82,
#   'Cloudiness': 43,
#   'Wind Speed': 0.76,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Aberdeen',
#   'Country': 'GB',
#   'Lat': 57.1437,
#   'Lng': -2.0981,
#   'Max Temp': 61.29,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Labytnangi',
#   'Country': 'RU',
#   'Lat': 66.6572,
#   'Lng': 66.4183,
#   'Max Temp': 48.69,
#   'Humidity': 97,
#   'Cloudiness': 98,
#   'Wind Speed': 10.25,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mecca',
#   'Country': 'SA',
#   'Lat': 21.4267,
#   'Lng': 39.8261,
#   'Max Temp': 85.62,
#   'Humidity': 29,
#   'Cloudiness': 3,
#   'Wind Speed': 5.35,
#   'Current Description': 'clear sky'},
#  {'City': 'Luwuk',
#   'Country': 'ID',
#   'Lat': -0.9516,
#   'Lng': 122.7875,
#   'Max Temp': 75.4,
#   'Humidity': 88,
#   'Cloudiness': 73,
#   'Wind Speed': 3.98,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vila Franca Do Campo',
#   'Country': 'PT',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 77.2,
#   'Humidity': 80,
#   'Cloudiness': 92,
#   'Wind Speed': 2.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chojnow',
#   'Country': 'PL',
#   'Lat': 51.2737,
#   'Lng': 15.9366,
#   'Max Temp': 48.27,
#   'Humidity': 85,
#   'Cloudiness': 70,
#   'Wind Speed': 8.86,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nuuk',
#   'Country': 'GL',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 39.81,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bonthe',
#   'Country': 'SL',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 76.77,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 8.1,
#   'Current Description': 'light rain'},
#  {'City': 'Arlit',
#   'Country': 'NE',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 93.67,
#   'Humidity': 30,
#   'Cloudiness': 82,
#   'Wind Speed': 7.63,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dudinka',
#   'Country': 'RU',
#   'Lat': 69.4058,
#   'Lng': 86.1778,
#   'Max Temp': 27.63,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 11.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Half Moon Bay',
#   'Country': 'US',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 80.55,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Current Description': 'few clouds'},
#  {'City': 'Ginda',
#   'Country': 'IN',
#   'Lat': 30.6945,
#   'Lng': 78.4932,
#   'Max Temp': 63.03,
#   'Humidity': 86,
#   'Cloudiness': 91,
#   'Wind Speed': 3.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 38.3,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 15.99,
#   'Current Description': 'light rain'},
#  {'City': 'Sitka',
#   'Country': 'US',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 57.09,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Uyuni',
#   'Country': 'BO',
#   'Lat': -20.4597,
#   'Lng': -66.825,
#   'Max Temp': 52.77,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 31.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Beidao',
#   'Country': 'CN',
#   'Lat': 34.5686,
#   'Lng': 105.8933,
#   'Max Temp': 52.61,
#   'Humidity': 92,
#   'Cloudiness': 87,
#   'Wind Speed': 2.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Stokmarknes',
#   'Country': 'NO',
#   'Lat': 68.5646,
#   'Lng': 14.9108,
#   'Max Temp': 48.16,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 53.64,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kontagora',
#   'Country': 'NG',
#   'Lat': 10.3999,
#   'Lng': 5.4695,
#   'Max Temp': 72.27,
#   'Humidity': 94,
#   'Cloudiness': 6,
#   'Wind Speed': 2.48,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Macquarie',
#   'Country': 'AU',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 56.89,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 11.05,
#   'Current Description': 'moderate rain'},
#  {'City': 'Miles City',
#   'Country': 'US',
#   'Lat': 46.4083,
#   'Lng': -105.8406,
#   'Max Temp': 61.77,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Syamzha',
#   'Country': 'RU',
#   'Lat': 60.0158,
#   'Lng': 41.0614,
#   'Max Temp': 48,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 9.37,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Burnie',
#   'Country': 'AU',
#   'Lat': -41.0667,
#   'Lng': 145.9167,
#   'Max Temp': 51.94,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 7.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 54.91,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Naze',
#   'Country': 'JP',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 68.92,
#   'Humidity': 75,
#   'Cloudiness': 3,
#   'Wind Speed': 8.12,
#   'Current Description': 'clear sky'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 24.89,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 18.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Baltay',
#   'Country': 'RU',
#   'Lat': 52.4652,
#   'Lng': 46.6308,
#   'Max Temp': 55.92,
#   'Humidity': 67,
#   'Cloudiness': 52,
#   'Wind Speed': 6.15,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tombouctou',
#   'Country': 'ML',
#   'Lat': 20,
#   'Lng': -3,
#   'Max Temp': 95.31,
#   'Humidity': 30,
#   'Cloudiness': 30,
#   'Wind Speed': 7.45,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Olafsvik',
#   'Country': 'IS',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 50.47,
#   'Humidity': 90,
#   'Cloudiness': 89,
#   'Wind Speed': 10.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Wangqing',
#   'Country': 'CN',
#   'Lat': 43.3218,
#   'Lng': 129.7634,
#   'Max Temp': 37.11,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Current Description': 'clear sky'},
#  {'City': 'Lohardaga',
#   'Country': 'IN',
#   'Lat': 23.4333,
#   'Lng': 84.6833,
#   'Max Temp': 71.92,
#   'Humidity': 98,
#   'Cloudiness': 90,
#   'Wind Speed': 4.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nong Chik',
#   'Country': 'TH',
#   'Lat': 6.8436,
#   'Lng': 101.178,
#   'Max Temp': 78.55,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 7.49,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chardara',
#   'Country': 'KZ',
#   'Lat': 41.2547,
#   'Lng': 67.9692,
#   'Max Temp': 70.93,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 8.63,
#   'Current Description': 'clear sky'},
#  {'City': 'Champerico',
#   'Country': 'GT',
#   'Lat': 14.3,
#   'Lng': -91.9167,
#   'Max Temp': 90.14,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 9.19,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hit',
#   'Country': 'IQ',
#   'Lat': 33.6416,
#   'Lng': 42.8251,
#   'Max Temp': 87.21,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 3.65,
#   'Current Description': 'clear sky'},
#  {'City': 'Puro',
#   'Country': 'PH',
#   'Lat': 12.4841,
#   'Lng': 123.3827,
#   'Max Temp': 79.65,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.08,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Muros',
#   'Country': 'ES',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 69.84,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 6.69,
#   'Current Description': 'clear sky'},
#  {'City': 'Muzhi',
#   'Country': 'RU',
#   'Lat': 65.3667,
#   'Lng': 64.6667,
#   'Max Temp': 49.77,
#   'Humidity': 81,
#   'Cloudiness': 29,
#   'Wind Speed': 17.96,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Anton Lizardo',
#   'Country': 'MX',
#   'Lat': 19.05,
#   'Lng': -95.9833,
#   'Max Temp': 86.22,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 10.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chumikan',
#   'Country': 'RU',
#   'Lat': 54.7183,
#   'Lng': 135.315,
#   'Max Temp': 37.36,
#   'Humidity': 73,
#   'Cloudiness': 4,
#   'Wind Speed': 17.92,
#   'Current Description': 'clear sky'},
#  {'City': 'Klaksvik',
#   'Country': 'FO',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 52.72,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 10.04,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 87.82,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 24.16,
#   'Current Description': 'few clouds'},
#  {'City': 'Marabba',
#   'Country': 'SD',
#   'Lat': 12.35,
#   'Lng': 32.1833,
#   'Max Temp': 79.65,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 5.19,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Soyo',
#   'Country': 'AO',
#   'Lat': -6.1349,
#   'Lng': 12.3689,
#   'Max Temp': 73.81,
#   'Humidity': 87,
#   'Cloudiness': 35,
#   'Wind Speed': 9.08,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Baie-Saint-Paul',
#   'Country': 'CA',
#   'Lat': 47.4411,
#   'Lng': -70.4986,
#   'Max Temp': 54.99,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 4.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kangaatsiaq',
#   'Country': 'GL',
#   'Lat': 68.3065,
#   'Lng': -53.4641,
#   'Max Temp': 37.45,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 14.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Berdigestyakh',
#   'Country': 'RU',
#   'Lat': 62.0989,
#   'Lng': 126.6992,
#   'Max Temp': 24.75,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 5.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 53.46,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 12.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 75,
#   'Humidity': 95,
#   'Cloudiness': 52,
#   'Wind Speed': 3.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Los Llanos De Aridane',
#   'Country': 'ES',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 71.35,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fort Nelson',
#   'Country': 'CA',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': 54.99,
#   'Humidity': 47,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Labuhan',
#   'Country': 'ID',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 77.41,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 7.58,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Arrifes',
#   'Country': 'PT',
#   'Lat': 37.7667,
#   'Lng': -25.7,
#   'Max Temp': 75.24,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Rio Blanco',
#   'Country': 'MX',
#   'Lat': 18.8333,
#   'Lng': -97.15,
#   'Max Temp': 73.71,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 8.19,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 68.05,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Havre-Saint-Pierre',
#   'Country': 'CA',
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp': 57.56,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Chirongui',
#   'Country': 'YT',
#   'Lat': -12.9319,
#   'Lng': 45.1483,
#   'Max Temp': 75.13,
#   'Humidity': 78,
#   'Cloudiness': 24,
#   'Wind Speed': 6.15,
#   'Current Description': 'few clouds'},
#  {'City': 'Monastyryshche',
#   'Country': 'UA',
#   'Lat': 48.9909,
#   'Lng': 29.8047,
#   'Max Temp': 46.27,
#   'Humidity': 93,
#   'Cloudiness': 96,
#   'Wind Speed': 14.38,
#   'Current Description': 'moderate rain'},
#  {'City': 'Najran',
#   'Country': 'SA',
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Max Temp': 81.25,
#   'Humidity': 34,
#   'Cloudiness': 87,
#   'Wind Speed': 4.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 63.28,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 21.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dingle',
#   'Country': 'PH',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 75.88,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.1,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aripuana',
#   'Country': 'BR',
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp': 90.9,
#   'Humidity': 38,
#   'Cloudiness': 75,
#   'Wind Speed': 3.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tahta',
#   'Country': 'EG',
#   'Lat': 26.7693,
#   'Lng': 31.5021,
#   'Max Temp': 80.71,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Tromso',
#   'Country': 'NO',
#   'Lat': 69.6496,
#   'Lng': 18.957,
#   'Max Temp': 42.82,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Rundu',
#   'Country': 'NA',
#   'Lat': -17.9333,
#   'Lng': 19.7667,
#   'Max Temp': 64.06,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 7.47,
#   'Current Description': 'clear sky'},
#  {'City': 'Beaver Dam',
#   'Country': 'US',
#   'Lat': 43.4578,
#   'Lng': -88.8373,
#   'Max Temp': 78.42,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Skelleftea',
#   'Country': 'SE',
#   'Lat': 64.7507,
#   'Lng': 20.9528,
#   'Max Temp': 34.16,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Presidencia Roque Saenz Pena',
#   'Country': 'AR',
#   'Lat': -26.7852,
#   'Lng': -60.4388,
#   'Max Temp': 68.09,
#   'Humidity': 73,
#   'Cloudiness': 96,
#   'Wind Speed': 7.96,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Plouzane',
#   'Country': 'FR',
#   'Lat': 48.3833,
#   'Lng': -4.6167,
#   'Max Temp': 57.25,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 74.82,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fairbanks',
#   'Country': 'US',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': 46.36,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sioux Lookout',
#   'Country': 'CA',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 73.47,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kushiro',
#   'Country': 'JP',
#   'Lat': 42.975,
#   'Lng': 144.3747,
#   'Max Temp': 54.23,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aleksandrovskoye',
#   'Country': 'RU',
#   'Lat': 44.7142,
#   'Lng': 43.0008,
#   'Max Temp': 64.74,
# ...
#   'Max Temp': 77.79,
#   'Humidity': 84,
#   'Cloudiness': 67,
#   'Wind Speed': 17.6,
#   'Current Description': 'broken clouds'},
#  {'City': 'Usinsk',
#   'Country': 'RU',
#   'Lat': 65.9939,
#   'Lng': 57.5281,
#   'Max Temp': 49.48,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 21.43,
#   'Current Description': 'light rain'},
#  {'City': 'Agadez',
#   'Country': 'NE',
#   'Lat': 19.75,
#   'Lng': 10.25,
#   'Max Temp': 90.1,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 12.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Angra Dos Reis',
#   'Country': 'BR',
#   'Lat': -23.0067,
#   'Lng': -44.3181,
#   'Max Temp': 68.59,
#   'Humidity': 86,
#   'Cloudiness': 66,
#   'Wind Speed': 1.83,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tecoanapa',
#   'Country': 'MX',
#   'Lat': 16.5167,
#   'Lng': -98.75,
#   'Max Temp': 81.48,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 8.32,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Emilio Carranza',
#   'Country': 'MX',
#   'Lat': 19.9711,
#   'Lng': -96.6114,
#   'Max Temp': 81.54,
#   'Humidity': 77,
#   'Cloudiness': 86,
#   'Wind Speed': 8.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Terney',
#   'Country': 'RU',
#   'Lat': 45.0503,
#   'Lng': 136.6092,
#   'Max Temp': 42.57,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 6.67,
#   'Current Description': 'clear sky'},
#  {'City': 'Kindu',
#   'Country': 'CD',
#   'Lat': -2.95,
#   'Lng': 25.95,
#   'Max Temp': 71.24,
#   'Humidity': 84,
#   'Cloudiness': 43,
#   'Wind Speed': 0.96,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Buraydah',
#   'Country': 'SA',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 91.85,
#   'Humidity': 18,
#   'Cloudiness': 56,
#   'Wind Speed': 13.18,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bodden Town',
#   'Country': 'KY',
#   'Lat': 19.2833,
#   'Lng': -81.25,
#   'Max Temp': 86,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Carutapera',
#   'Country': 'BR',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 79.25,
#   'Humidity': 79,
#   'Cloudiness': 70,
#   'Wind Speed': 7.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Koroni',
#   'Country': 'GR',
#   'Lat': 36.8,
#   'Lng': 21.95,
#   'Max Temp': 69.51,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 6.26,
#   'Current Description': 'clear sky'},
#  {'City': 'Qiongshan',
#   'Country': 'CN',
#   'Lat': 20.0058,
#   'Lng': 110.3542,
#   'Max Temp': 75.18,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Nabire',
#   'Country': 'ID',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 74.62,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fez',
#   'Country': 'MA',
#   'Lat': 34.0372,
#   'Lng': -4.9998,
#   'Max Temp': 77.25,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'thunderstorm with rain'},
#  {'City': 'Ginir',
#   'Country': 'ET',
#   'Lat': 7.1333,
#   'Lng': 40.7,
#   'Max Temp': 64.36,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 1.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cozumel',
#   'Country': 'MX',
#   'Lat': 20.5083,
#   'Lng': -86.9458,
#   'Max Temp': 89.01,
#   'Humidity': 74,
#   'Cloudiness': 11,
#   'Wind Speed': 5.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Balkanabat',
#   'Country': 'TM',
#   'Lat': 39.5108,
#   'Lng': 54.3671,
#   'Max Temp': 80.76,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 8.43,
#   'Current Description': 'clear sky'},
#  {'City': 'Muisne',
#   'Country': 'EC',
#   'Lat': 0.6,
#   'Lng': -80.0333,
#   'Max Temp': 76.42,
#   'Humidity': 79,
#   'Cloudiness': 88,
#   'Wind Speed': 11.48,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lisakovsk',
#   'Country': 'KZ',
#   'Lat': 52.5369,
#   'Lng': 62.4936,
#   'Max Temp': 60.76,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Ostend',
#   'Country': 'BE',
#   'Lat': 51.2234,
#   'Lng': 2.9119,
#   'Max Temp': 57.09,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Seljord',
#   'Country': 'NO',
#   'Lat': 59.4894,
#   'Lng': 8.634,
#   'Max Temp': 42.4,
#   'Humidity': 79,
#   'Cloudiness': 7,
#   'Wind Speed': 3.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Atar',
#   'Country': 'MR',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 93.2,
#   'Humidity': 27,
#   'Cloudiness': 42,
#   'Wind Speed': 16.2,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Santa Maria',
#   'Country': 'BR',
#   'Lat': -29.6842,
#   'Lng': -53.8069,
#   'Max Temp': 70.9,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Ponta Delgada',
#   'Country': 'PT',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 77.5,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'San Jose',
#   'Country': 'US',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 80.58,
#   'Humidity': 41,
#   'Cloudiness': 75,
#   'Wind Speed': 8.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ganzhou',
#   'Country': 'CN',
#   'Lat': 28.8184,
#   'Lng': 115.4327,
#   'Max Temp': 67.51,
#   'Humidity': 60,
#   'Cloudiness': 95,
#   'Wind Speed': 6.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zhanakorgan',
#   'Country': 'KZ',
#   'Lat': 43.9098,
#   'Lng': 67.2495,
#   'Max Temp': 73.87,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 14.29,
#   'Current Description': 'clear sky'},
#  {'City': 'Yekaterinoslavka',
#   'Country': 'RU',
#   'Lat': 50.3734,
#   'Lng': 129.1139,
#   'Max Temp': 41.32,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 12.35,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yarmouth',
#   'Country': 'US',
#   'Lat': 41.7057,
#   'Lng': -70.2286,
#   'Max Temp': 66.34,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Iwanai',
#   'Country': 'JP',
#   'Lat': 42.9744,
#   'Lng': 140.5089,
#   'Max Temp': 49.42,
#   'Humidity': 69,
#   'Cloudiness': 58,
#   'Wind Speed': 3.27,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bandarbeyla',
#   'Country': 'SO',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 78.39,
#   'Humidity': 85,
#   'Cloudiness': 52,
#   'Wind Speed': 19.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Rocky Mountain House',
#   'Country': 'CA',
#   'Lat': 52.3668,
#   'Lng': -114.9188,
#   'Max Temp': 53.71,
#   'Humidity': 40,
#   'Cloudiness': 6,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Shimoda',
#   'Country': 'JP',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 63.1,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 15.19,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Svetlogorsk',
#   'Country': 'BY',
#   'Lat': 52.6333,
#   'Lng': 29.7333,
#   'Max Temp': 46.29,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 4.12,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mardin',
#   'Country': 'TR',
#   'Lat': 37.3131,
#   'Lng': 40.7436,
#   'Max Temp': 78.08,
#   'Humidity': 16,
#   'Cloudiness': 64,
#   'Wind Speed': 8.79,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jadu',
#   'Country': 'LY',
#   'Lat': 31.953,
#   'Lng': 12.0261,
#   'Max Temp': 77.61,
#   'Humidity': 34,
#   'Cloudiness': 2,
#   'Wind Speed': 3.42,
#   'Current Description': 'clear sky'},
#  {'City': 'Finote Selam',
#   'Country': 'ET',
#   'Lat': 10.7,
#   'Lng': 37.2667,
#   'Max Temp': 58.15,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'moderate rain'},
#  {'City': 'Adamovka',
#   'Country': 'RU',
#   'Lat': 51.5223,
#   'Lng': 59.9396,
#   'Max Temp': 60.46,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 6.42,
#   'Current Description': 'clear sky'},
#  {'City': 'Pietersburg',
#   'Country': 'ZA',
#   'Lat': -23.9045,
#   'Lng': 29.4688,
#   'Max Temp': 57.02,
#   'Humidity': 90,
#   'Cloudiness': 57,
#   'Wind Speed': 8.23,
#   'Current Description': 'moderate rain'},
#  {'City': 'Finnsnes',
#   'Country': 'NO',
#   'Lat': 69.2296,
#   'Lng': 17.9811,
#   'Max Temp': 41.61,
#   'Humidity': 77,
#   'Cloudiness': 94,
#   'Wind Speed': 4.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sartell',
#   'Country': 'US',
#   'Lat': 45.6216,
#   'Lng': -94.2069,
#   'Max Temp': 87.19,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sovetskaya Gavan',
#   'Country': 'RU',
#   'Lat': 48.9723,
#   'Lng': 140.2878,
#   'Max Temp': 39.43,
#   'Humidity': 63,
#   'Cloudiness': 2,
#   'Wind Speed': 8.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Kokopo',
#   'Country': 'PG',
#   'Lat': -4.352,
#   'Lng': 152.2633,
#   'Max Temp': 76.06,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.67,
#   'Current Description': 'light rain'},
#  {'City': 'Salmas',
#   'Country': 'IR',
#   'Lat': 38.1973,
#   'Lng': 44.7653,
#   'Max Temp': 68.25,
#   'Humidity': 18,
#   'Cloudiness': 35,
#   'Wind Speed': 5.84,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Thinadhoo',
#   'Country': 'MV',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 80.42,
#   'Humidity': 76,
#   'Cloudiness': 17,
#   'Wind Speed': 4.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Adre',
#   'Country': 'TD',
#   'Lat': 13.4667,
#   'Lng': 22.2,
#   'Max Temp': 78.73,
#   'Humidity': 58,
#   'Cloudiness': 87,
#   'Wind Speed': 3.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tingi',
#   'Country': 'TZ',
#   'Lat': -11.3,
#   'Lng': 35.0333,
#   'Max Temp': 64.42,
#   'Humidity': 64,
#   'Cloudiness': 2,
#   'Wind Speed': 6.26,
#   'Current Description': 'clear sky'},
#  {'City': 'Robertsport',
#   'Country': 'LR',
#   'Lat': 6.7533,
#   'Lng': -11.3686,
#   'Max Temp': 77.18,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 11.77,
#   'Current Description': 'light rain'},
#  {'City': 'Santa Marta',
#   'Country': 'CO',
#   'Lat': 11.2408,
#   'Lng': -74.199,
#   'Max Temp': 86.9,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Current Description': 'light intensity drizzle'},
#  {'City': 'Nevers',
#   'Country': 'FR',
#   'Lat': 46.9167,
#   'Lng': 3.3333,
#   'Max Temp': 49.69,
#   'Humidity': 67,
#   'Cloudiness': 99,
#   'Wind Speed': 4.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kosterevo',
#   'Country': 'RU',
#   'Lat': 55.9299,
#   'Lng': 39.6144,
#   'Max Temp': 46.44,
#   'Humidity': 89,
#   'Cloudiness': 55,
#   'Wind Speed': 2.53,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kamenka',
#   'Country': 'RU',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 53.71,
#   'Humidity': 58,
#   'Cloudiness': 97,
#   'Wind Speed': 6.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Alekseyevka',
#   'Country': 'RU',
#   'Lat': 50.6309,
#   'Lng': 38.6903,
#   'Max Temp': 55.8,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 8.25,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Valentin Gomez Farias',
#   'Country': 'MX',
#   'Lat': 28.2167,
#   'Lng': -106.5833,
#   'Max Temp': 77.85,
#   'Humidity': 46,
#   'Cloudiness': 60,
#   'Wind Speed': 12.26,
#   'Current Description': 'broken clouds'},
#  {'City': 'Calabozo',
#   'Country': 'VE',
#   'Lat': 8.9242,
#   'Lng': -67.4293,
#   'Max Temp': 85.28,
#   'Humidity': 70,
#   'Cloudiness': 81,
#   'Wind Speed': 4.34,
#   'Current Description': 'broken clouds'},
#  {'City': 'Genhe',
#   'Country': 'CN',
#   'Lat': 50.7833,
#   'Lng': 121.5167,
#   'Max Temp': 41.43,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tabat',
#   'Country': 'ID',
#   'Lat': -2.635,
#   'Lng': 115.2274,
#   'Max Temp': 71.82,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Forbes',
#   'Country': 'AU',
#   'Lat': -33.3833,
#   'Lng': 148.0167,
#   'Max Temp': 61.92,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 8.97,
#   'Current Description': 'moderate rain'},
#  {'City': 'Khilok',
#   'Country': 'RU',
#   'Lat': 51.3674,
#   'Lng': 110.4676,
#   'Max Temp': 42.37,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 11.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dzhebariki-Khaya',
#   'Country': 'RU',
#   'Lat': 62.2167,
#   'Lng': 135.8,
#   'Max Temp': 24.71,
#   'Humidity': 74,
#   'Cloudiness': 5,
#   'Wind Speed': 3.27,
#   'Current Description': 'clear sky'},
#  {'City': 'Kutum',
#   'Country': 'SD',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 76.3,
#   'Humidity': 53,
#   'Cloudiness': 52,
#   'Wind Speed': 5.46,
#   'Current Description': 'broken clouds'},
#  {'City': 'Quibor',
#   'Country': 'VE',
#   'Lat': 9.9287,
#   'Lng': -69.6201,
#   'Max Temp': 83.37,
#   'Humidity': 64,
#   'Cloudiness': 99,
#   'Wind Speed': 1.86,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Holovyne',
#   'Country': 'UA',
#   'Lat': 50.4712,
#   'Lng': 28.8253,
#   'Max Temp': 47.64,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 9.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barranquilla',
#   'Country': 'CO',
#   'Lat': 10.9639,
#   'Lng': -74.7964,
#   'Max Temp': 80.38,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Naica',
#   'Country': 'MX',
#   'Lat': 27.85,
#   'Lng': -105.4833,
#   'Max Temp': 84.79,
#   'Humidity': 36,
#   'Cloudiness': 65,
#   'Wind Speed': 9.42,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mega',
#   'Country': 'ET',
#   'Lat': 4.05,
#   'Lng': 38.3,
#   'Max Temp': 63.84,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 10.42,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Escondido',
#   'Country': 'MX',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 80.74,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Konevo',
#   'Country': 'RU',
#   'Lat': 62.1215,
#   'Lng': 39.3192,
#   'Max Temp': 46.38,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 7.78,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bangangte',
#   'Country': 'CM',
#   'Lat': 5.1409,
#   'Lng': 10.5198,
#   'Max Temp': 61.05,
#   'Humidity': 97,
#   'Cloudiness': 85,
#   'Wind Speed': 2.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nueva Loja',
#   'Country': 'EC',
#   'Lat': 0.0847,
#   'Lng': -76.8828,
#   'Max Temp': 89.62,
#   'Humidity': 51,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Alcudia',
#   'Country': 'ES',
#   'Lat': 39.8532,
#   'Lng': 3.1214,
#   'Max Temp': 75.25,
#   'Humidity': 63,
#   'Cloudiness': 9,
#   'Wind Speed': 3.89,
#   'Current Description': 'clear sky'},
#  {'City': 'Mamontovo',
#   'Country': 'RU',
#   'Lat': 52.7055,
#   'Lng': 81.6244,
#   'Max Temp': 53.71,
#   'Humidity': 69,
#   'Cloudiness': 68,
#   'Wind Speed': 6.35,
#   'Current Description': 'broken clouds'},
#  {'City': 'Samana',
#   'Country': 'DO',
#   'Lat': 19.2056,
#   'Lng': -69.3369,
#   'Max Temp': 86.22,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sabha',
#   'Country': 'LY',
#   'Lat': 27.0377,
#   'Lng': 14.4283,
#   'Max Temp': 89.69,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 7.31,
#   'Current Description': 'clear sky'},
#  {'City': 'Trinidad',
#   'Country': 'BO',
#   'Lat': -14.8333,
#   'Lng': -64.9,
#   'Max Temp': 98.58,
#   'Humidity': 41,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Current Description': 'smoke'},
#  {'City': 'Bonaventure',
#   'Country': 'CA',
#   'Lat': 48.0457,
#   'Lng': -65.4926,
#   'Max Temp': 55.98,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Current Description': 'light rain'},
#  {'City': 'Amazar',
#   'Country': 'RU',
#   'Lat': 53.858,
#   'Lng': 120.875,
#   'Max Temp': 32.7,
#   'Humidity': 94,
#   'Cloudiness': 43,
#   'Wind Speed': 1.59,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jiblah',
#   'Country': 'YE',
#   'Lat': 13.9216,
#   'Lng': 44.1467,
#   'Max Temp': 65.64,
#   'Humidity': 58,
#   'Cloudiness': 99,
#   'Wind Speed': 5.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tynda',
#   'Country': 'RU',
#   'Lat': 55.1667,
#   'Lng': 124.7167,
#   'Max Temp': 31.19,
#   'Humidity': 94,
#   'Cloudiness': 92,
#   'Wind Speed': 1.07,
#   'Current Description': 'overcast clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Carnarvon      AU -24.8667  113.6333     63.91        59          96
# 1      Mataura      NZ -46.1927  168.8643     46.47        97          99
# 2     Hokitika      NZ -42.7167  170.9667     53.55        75          80
# 3  Provideniya      RU  64.3833 -173.3000     39.36       100          53
# 4        Lagoa      PT  39.0500  -27.9833     73.96        82          18
# 5  Port Alfred      ZA -33.5906   26.8910     58.62        75          10
# 6         Chuy      UY -33.6971  -53.4616     53.73        79         100
# 7        Bluff      NZ -46.6000  168.3333     46.80        87         100
# 8  Clyde River      CA  70.4692  -68.5914     32.23        86          75
# 9    Cape Town      ZA -33.9258   18.4232     64.38        67           0
#
#    Wind Speed Current Description
# 0       12.66     overcast clouds
# 1        0.72     overcast clouds
# 2        3.15       broken clouds
# 3        4.00       broken clouds
# 4        5.77          few clouds
# 5        9.31           clear sky
# 6       10.74     overcast clouds
# 7        2.42     overcast clouds
# 8        5.75                snow
# 9        9.22           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
